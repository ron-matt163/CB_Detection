# %%
import tweepy 
import sys
# Fill the X's with the credentials obtained by  
# following the above mentioned procedure. 
auth = tweepy.OAuthHandler('ac8YRucGrIbNHUcD2IYqpfp4s', 'ymifAZlIIJAVDqGfxcrVcmPCiEXYhxRUqyh43KVvyxmuuYG2s3')
auth.set_access_token('1033620667155984384-uKKn6iHzAan304XrH5nU8evIQJUwak', '6TcRuKZE4EGx5F2XTCavopZdttlw380Ms8MoyyMqZqiS2')
api = tweepy.API(auth, wait_on_rate_limit=True)

public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# @FFScout_Mark Kane and Wilson in a 3-5-2 could be what I look at up front... in which case I’ll only have 2 of my planned fh already.
# Found another bottle of vodka, we move 🤑🤑🥵☺️🔥😴👁️😅☺️
# No brainer with DGW19 in mind right? 👀 https://t.co/cH6M4e9nMx
# @FFScout_Mark @FFScout_Joe I was wavering after your earlier post, Mark! But I’ve firmly talked myself *back into*… https://t.co/Otn7aksVHA
# I’m currently benching Chilwell in GW16. Crazy? Anyone else? #FPL
# Yes, but the initial squad will be the same as it is at GW17 deadline.
#
# 1 free transfer after a free hit https://t.co/EjJjP7uKbr
# How to mitigate risk in #FPL was the discussion on the latest @FPLDoubleUp podcast 🤔
#
# Great listen as always… https://t.co/ebWQcWZfEY
# Of course https://t.co/5XLfkCVOK5
# @FFScout_Joe Yeah it’s the forward options. You can’t BB in 19 and also have good options for 18. Watkins and Wood… https://t.co/Zv1236fAhb
# #GW17 captaincy ©️👇🏼
# RT @Ajayabhujel22: Captaincy pool for GW17
# #fpl #GW17
# If you’re free hitting in GW18 your GW19 squad will look exactly the same as it does at 4pm today 👍
#
# Hope that helps.
# @LetsTalk_FPL Wouldn’t*****
# @LetsTalk_FPL For what it’s worth I would get too fixated on one player. Salah, Bruno and even Vardy have proven th… https://t.co/tcLmz8xZ3a
# @MesutOzil1088 You look devastated. What's wrong
# ⭐️ NEW #FPL ARTICLE ⭐️
#
# The superb @BigManBakar answers the big questions ahead of #GW17 🔥
#
# ✅ Best GW17 captain
# ✅… https://t.co/tNnpUX1ZAP
# Never has one Belgian given me such a headache. https://t.co/qUAdBjuGuk
# Happy New Year everyone🥳We're all excited to leave 2020 behind for 2021 but know that millions of people still got… https://t.co/U0NMBKjA6O
# Are you locked in for #FPL GW17?
#
# Send us a screenshot of your team!
# The 1st day of 2⃣0⃣2⃣1⃣ is Friday ❤️ Alhamdulillah 🤲🏼
# May God bless you all with good health and happiness this yea… https://t.co/hgKfaMmDZM

# %%
import tweepy
import os
import json
import sys
import geocoder
from langdetect import detect

def isEnglish(s):
    try:
        s.encode(encoding='utf-8').decode('ascii')
    except UnicodeDecodeError:
        return False
    else:
        return True

# API Keys and Tokens

# Authorization and Authentication

date_since="2020-12-01"

if __name__ == "__main__":
    # Available Locations
    available_loc = api.trends_available()
    # writing a JSON file that has the available trends around the world
    with open("available_locs_for_trend.json","w") as wp:
        wp.write(json.dumps(available_loc, indent=1))

    # Trends for Specific Country     # location as argument variable 
    g = geocoder.osm('India') # getting object that has location's latitude and longitude

    closest_loc = api.trends_closest(g.lat, g.lng)
    trends = api.trends_place(closest_loc[0]['woeid'],count=200,lang="en")
    # writing a JSON file that has the latest trends for that location
    print("The top trends for the location are :") 
    for value in trends: 
        for trend in value['trends']:
            if isEnglish(trend['name']):
                print(trend['name'])
# Out:
# The top trends for the location are :
# #MasterFilm
# #contributeforrammandir
# YRF ANNOUNCE PATHAN
# Ranbir In Animal
# Sufiscore Despacito
# GovNow With Maj GDBakshi
# DCGI
# Rs 1.15
# HBD UMAR RIAZ
# Rohit Sharma
# Success
# Thalaivaa
# Serum Institute
# Happy New Year Hobi
# Umesh Yadav
# Thalapathy
# The Messiah
# Trailer
# Happy New Year Sir
# Nattu
# New Year's Day
# Happy New Year Anna
# Shardul
# Monie
# Saini
# Mahindra
# Light House Projects
# ISRO
# GHTC-India
# Very Happy New Year 2021
# Happy and Prosperous New Year
# Thakur
# SHINee
# #MasterPongal
# #covishield
# #MasterEmoji
# #Karnan
# #FreeHinduTemples
# #Andhagan
# #NewYear4Sushant
# #newbeginnings
# #Shaakuntalam
# #HitlerModiAgainstFarmers
# #Mumbaikar

# %%
import re
from nltk.stem import WordNetLemmatizer

def message_cleaning(message):
    message = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",message).split())
    Test_punc_removed = [char for char in message if char not in string.punctuation]
    Test_punc_removed_join = ''.join(Test_punc_removed)
    Test_punc_removed_join_clean = [word.lower() for word in Test_punc_removed_join.split() if word.lower() not in stopwords.words('english')]
    wordnet_lemmatizer = WordNetLemmatizer()
    lemma_list = [wordnet_lemmatizer.lemmatize(word) for word in Test_punc_removed_join_clean]
    
    return lemma_list

# %%
count = 0
for value in trends: 
    for trend in value['trends']:
        if isEnglish(trend['name']): 
            print(trend['name'])
            tweets = tweepy.Cursor(api.search, q=trend['name'],lang="en", since=date_since,result_type='popular', timeout=999999).items(10)
            for tweet in tweets:
                print("Tweet:\n")
                cleaned_tweet = message_cleaning(tweet.text)
                print(cleaned_tweet)
                tweet_id = tweet.id
                print("Tweet ID: " + str(tweet_id))
                poster = tweet.user.screen_name
                print("\nPoster: " + poster + "\n")
                print("Replies to this tweet: \n")
                replies = tweepy.Cursor(api.search,q="@"+poster, since_id=tweet_id).items(50)
                #print(type(replies))
                count = 0
                for reply in replies:
                    if(reply.in_reply_to_status_id == tweet_id):
                        cleaned_reply = message_cleaning(reply.text)
                        print(cleaned_reply)
                        count +=1
                    if count==10:
                        break                
            count +=1
        if count==5:
            break
# Out:
# #MasterFilm
# Tweet:
#
# ['happy', 'new', 'year', 'master', 'fans', 'tweet', 'masterfilm', 'masterpongal']
# Tweet ID: 1344986811064487937
#
# Poster: TwitterIndia
#
# Replies to this tweet:
#
# Tweet:
#
# ['masterfilm', 'masterpongal', 'vijaythemaster', 'thank', 'masteremoji']
# Tweet ID: 1344984304326098946
#
# Poster: XBFilmCreators
#
# Replies to this tweet:
#
# Tweet:
#
# ['special', 'new', 'year', 'gift', 'thalapathy', 'fans', 'tweet', 'masterfilm', 'masterpongal']
# Tweet ID: 1344992432237154305
#
# Poster: XBFilmCreators
#
# Replies to this tweet:
#
# ['masterpongal']
# ['masterpongal']
# ['masterfilm']
# ['masterpongal', 'masterpongal']
# ['masterpongal', 'verithanamaana', 'waiting']
# Tweet:
#
# ['emoji', 'arrived', 'style', 'celebrations', 'officially', 'begins', 'masterfilm', 'masterpongal']
# Tweet ID: 1344985436150661121
#
# Poster: sekartweets
#
# Replies to this tweet:
#
# ['naa', 'tweet', 'panniten', 'epdi', 'master', 'emoji', 'vaanguradhu', 'bro']
# Tweet:
#
# ['masteremoji', 'activated', '3rd', 'film', 'get', 'twitter', 'emoji', 'masterfilm', 'masterpongal', 'vijaythemaster']
# Tweet ID: 1344987351974510593
#
# Poster: thusi_c
#
# Replies to this tweet:
#
# Tweet:
#
# ['masterfilm', 'emoji', 'master', 'thalapathyvijay']
# Tweet ID: 1344985595521748993
#
# Poster: IamSellvah
#
# Replies to this tweet:
#
# Tweet:
#
# ['happy', 'new', 'year', 'activates', 'master', 'emoji', 'style', 'masterfilm', 'masterpongal']
# Tweet ID: 1344988493093638145
#
# Poster: sri50
#
# Replies to this tweet:
#
# Tweet:
#
# ['tweet', 'masterfilm', 'masterpongal', 'vijaythemaster', 'unlock', 'masteremoji']
# Tweet ID: 1344988467726409729
#
# Poster: KollyBuzz
#
# Replies to this tweet:
#
# Tweet:
#
# ['visibility', 'masterfilm', 'emojis', 'android', 'mobiles', 'tags', 'vijaythemaster', 'emoj']
# Tweet ID: 1344990577247580163
#
# Poster: IamSellvah
#
# Replies to this tweet:
#
# Tweet:
#
# ['thalapathyvijay', 'gets', 'masteremoji', 'upcoming', 'film', 'master', 'directed', 'lokesh', 'masterpongal']
# Tweet ID: 1344990126447837186
#
# Poster: ChennaiTimesTOI
#
# Replies to this tweet:
#
# #contributeforrammandir
# Tweet:
#
# ['donate', 'shree', 'ram', 'mandir', 'contributeforrammandir']
# Tweet ID: 1344942549841022976
#
# Poster: beingarun28
#
# Replies to this tweet:
#
# ['please', 'give', 'details', 'want', 'pay']
# Tweet:
#
# ['starting', 'trend', 'ram', 'mandir', 'contributeforrammandir']
# Tweet ID: 1344939033617567746
#
# Poster: beingarun28
#
# Replies to this tweet:
#
# Tweet:
#
# ['giving', 'follow', 'back', 'every', 'nationalist', '1', 'rt', 'tweet', '2', 'comment', 'contributeforrammandir']
# Tweet ID: 1344947135351902208
#
# Poster: amarprasadreddy
#
# Replies to this tweet:
#
# ['kumawat']
# Tweet:
#
# ['dear', 'hindustan', 'hindus', 'contributeforrammandir']
# Tweet ID: 1344946445040799744
#
# Poster: ashishMib
#
# Replies to this tweet:
#
# ['donate', 'hm', 'bhi', 'krna', 'chahte', 'hai', 'lekin', 'aapne', 'sirf', 'hinduo', 'ko', 'kaha', 'hai']
# ['koi', 'link', 'diziye', 'jispe', 'send', 'kiya', 'ja', 'ske']
# ['biggestrevelationof2021']
# ['understand', 'guys', 'spent', 'millions', 'rath', 'yatra', 'horse', 'trading', 'online', 'troll', 'army', 'godi', 'media']
# ['bhik', 'hi', 'mangte', 'rhna', 'dharam', 'k', 'naam', 'pr', 'desh', 'bechte', 'rhna']
# ['like', 'every', 'indian', 'contributed', '10rs', 'schools', 'hospitals', 'would', 'developed', 'country']
# Tweet:
#
# ['retweet', 'ram', 'bhakt', 'contributeforrammandir']
# Tweet ID: 1344943595954978817
#
# Poster: dineshbjp09
#
# Replies to this tweet:
#
# Tweet:
#
# ['entire', 'struggle', 'liberation', 'ram', 'jnmbhumi', 'religious', 'one', 'whether', 'continuous', 'social', 'e']
# Tweet ID: 1344944802874343425
#
# Poster: varunpuri1984
#
# Replies to this tweet:
#
# ['preplanned', 'demolition', 'shameless', 'bhagwa', 'atankwadi', 'demolished', 'babri', 'masjid', 'may', 'ram', 'put', 'hell']
# ['inme', 'se', 'kaun', 'hain', 'aur', 'kaun', 'hain']
# Tweet:
#
# ['15k', 'tweets', 'congratulations', 'contributeforrammandir']
# Tweet ID: 1344949460405690368
#
# Poster: hariompandeyMP
#
# Replies to this tweet:
#
# Tweet:
#
# ['retweet', 'maximum', 'amp', 'write', 'contributeforrammandir']
# Tweet ID: 1344947316755558400
#
# Poster: hariompandeyMP
#
# Replies to this tweet:
#
# Tweet:
#
# ['wait', 'nearly', '500', 'years', 'one', 'lucky', 'living', 'generation', 'witness', 'ram', 'mandir']
# Tweet ID: 1344943013466759169
#
# Poster: snshriraj
#
# Replies to this tweet:
#
# ['coronavirus', 'covidals20', 'contributeforrammandir']
# ['contributeforrammandir']
# ['contributeforrammandir']
# YRF ANNOUNCE PATHAN

# %% [markdown]
# # Classifying live tweets

# %%
import pickle
with open('../Count vectorizer feature extraction/NBBoWTrained.sav', 'rb') as f:
    loaded_NB_classifier,loaded_func_countvectorizer = pickle.load(f)

# %%
count = 0
for value in trends: 
    for trend in value['trends']:
        if isEnglish(trend['name']): 
            print(trend['name'])
            tweets = tweepy.Cursor(api.search, q=trend['name'],lang="en", since=date_since,result_type='popular', timeout=999999).items(10)
            for tweet in tweets:
                print("Tweet:\n")
                cleaned_tweet = message_cleaning(tweet.text)
                print(cleaned_tweet)
                tweet_id = tweet.id
                print("Tweet ID: " + str(tweet_id))
                poster = tweet.user.screen_name
                print("\nPoster: " + poster + "\n")
                print("Replies to this tweet: \n")
                replies = tweepy.Cursor(api.search,q="@"+poster, since_id=tweet_id).items(1000)
                #print(type(replies))
                count = 0
                for reply in replies:
                    if(reply.in_reply_to_status_id == tweet_id):
                        input_text = []
                        input_text.append(reply.text)
                        print(input_text)
                        input_vector = loaded_func_countvectorizer.transform(input_text)
                        result = loaded_NB_classifier.predict(input_vector)
                        print("\nClassification:\n")
                        print(result)
                    if count==10:
                        break                
            count +=1
        if count==5:
            break
# Out:
# #MasterFilm
# Tweet:
#
# ['happy', 'new', 'year', 'master', 'fan', 'tweet', 'masterfilm', 'masterpongal']
# Tweet ID: 1344986811064487937
#
# Poster: TwitterIndia
#
# Replies to this tweet:
#
# ['@TwitterIndia @actorvijay Wish you happy New Year']
#
# Classification:
#
# [0]
# ['@TwitterIndia @actorvijay Master pongal']
#
# Classification:
#
# [0]
# ['@TwitterIndia @actorvijay #MasterPongal']
#
# Classification:
#
# [0]
# ['@TwitterIndia @actorvijay #masterfilm https://t.co/NIEtLYZa50']
#
# Classification:
#
# [0]
# ['@TwitterIndia @actorvijay #MasterFilm\n#Masterpongal\n#VijayTheMaster\n#மாஸ்டர்\n#మాస్టర్ \n@ActorVijay\n#Thalapathy65']
#
# Classification:
#
# [0]
# ['@TwitterIndia @actorvijay #Masterflim']
#
# Classification:
#
# [0]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-09e4263aa8a5> in <module>
#      17                 #print(type(replies))
#      18                 count = 0
# ---> 19                 for reply in replies:
#      20                     if(reply.in_reply_to_status_id == tweet_id):
#      21                         input_text = []
#
# ~/.local/lib/python3.6/site-packages/tweepy/cursor.py in __next__(self)
#      47
#      48     def __next__(self):
# ---> 49         return self.next()
#      50
#      51     def next(self):
#
# ~/.local/lib/python3.6/site-packages/tweepy/cursor.py in next(self)
#     217         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     218             # Reached end of current page, get the next page...
# --> 219             self.current_page = self.page_iterator.next()
#     220             while len(self.current_page) == 0:
#     221                 self.current_page = self.page_iterator.next()
#
# ~/.local/lib/python3.6/site-packages/tweepy/cursor.py in next(self)
#     128
#     129         if self.index >= len(self.results) - 1:
# --> 130             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     131
#     132             if hasattr(self.method, '__self__'):
#
# ~/.local/lib/python3.6/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     250                 return method
#     251             else:
# --> 252                 return method.execute()
#     253         finally:
#     254             method.session.close()
#
# ~/.local/lib/python3.6/site-packages/tweepy/binder.py in execute(self)
#     188                                                 timeout=self.api.timeout,
#     189                                                 auth=auth,
# --> 190                                                 proxies=self.api.proxy)
#     191                 except Exception as e:
#     192                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#
# ~/.local/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/.local/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/.local/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     704                 body=body,
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#     708
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/.local/lib/python3.6/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# /usr/lib/python3.6/http/client.py in getresponse(self)
#    1371         try:
#    1372             try:
# -> 1373                 response.begin()
#    1374             except ConnectionError:
#    1375                 self.close()
#
# /usr/lib/python3.6/http/client.py in begin(self)
#     309         # read until we get a non-100 response
#     310         while True:
# --> 311             version, status, reason = self._read_status()
#     312             if status != CONTINUE:
#     313                 break
#
# /usr/lib/python3.6/http/client.py in _read_status(self)
#     270
#     271     def _read_status(self):
# --> 272         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     273         if len(line) > _MAXLINE:
#     274             raise LineTooLong("status line")
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /usr/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# # Trying StreamListener

# %%
import tweepy
#override tweepy.StreamListener to add logic to on_status


class MyStreamListener(tweepy.StreamListener):

    def on_status(self, status):
        if 'RT @' in status.text:
            return
        print("\nTweet:")
        print(status.text)
        print("\nPosted by:")
        poster = status.user.screen_name
        print(poster)
        print("\nReplies to the tweet:")
        tweet_id = status.id
        replies = tweepy.Cursor(api.search,q="@"+poster, since_id=tweet_id).items(25)
        count = 0
        for reply in replies:
            if(reply.in_reply_to_status_id == tweet_id):
                print(reply.text)
                count +=1
            if count==50:
                break                        

myStreamListener = MyStreamListener()
myStream = tweepy.Stream(auth = api.auth, listener=myStreamListener)

for value in trends: 
    for trend in value['trends']:
        if isEnglish(trend['name']):
            myStream.filter(track=[trend['name']],languages=['en'])
# Out:
# Tweet:
# 😍100K Likes❤for😎 @actorvijay Anna❤ 😉Tweet !🔥
#
# #MasterFilm #மாஸ்டர் https://t.co/rejn0CYfu2
#
# Posted by:
# VijayAlagendran
#
# Replies to the tweet:
#
# Tweet:
# Kerala Health minister #shailajateacher About Thalapathy Vijay Fans Requests For #MasterFilm Kerala Theatre Release… https://t.co/d1PchIMNth
#
# Posted by:
# _dfyy_
#
# Replies to the tweet:
#
# Tweet:
# #Master has 86.7k users shown interest on @bookmyshow . #MasterPongal . #మాస్టర్ #MasterFilm . All that you would l… https://t.co/4944w6MrCa
#
# Posted by:
# Pakkudu4
#
# Replies to the tweet:
#
# Tweet:
# Full dominance!!!
#
# Top 5 Hashtags Related to #Masterfilm is Trending. #Master @actorvijay ! #MasterFilm https://t.co/RBEPQ4rnh3
#
# Posted by:
# pulzerBLUE
#
# Replies to the tweet:
#
# Tweet:
# Very Rare For Vijay Fans But Not For @urstrulyMahesh Fans 😎
#
# #SarkaruVaariPaata @urstrulyMahesh… https://t.co/V0XM7pkUg6
#
# Posted by:
# _MaheshBabuFan
#
# Replies to the tweet:
#
# Tweet:
# Good night 😴
# #MasterFilm
#
# #MasterFilm
# #MasterPongal
# #மாஸ்டர்
# #మాస్టర్
# #VijayTheMaster
#
# Posted by:
# Rejitha_Vijay
#
# Replies to the tweet:
#
# Tweet:
# @actorvijay @TwitterIndia Unexpected thalaivaaa 🔥🔥🔥❤️❤️❤️
# #மாஸ்டர்
#
# #MasterFilm
#
# #మాస్టర్
#
# #MasterPongal… https://t.co/BStNSMXWU8
#
# Posted by:
# Master_Kanan
#
# Replies to the tweet:
#
# Tweet:
# Good Nite Thalapathians ✨
#
# #HappyNewYear2021 #MasterFilm #Welcome2021 #MasterPongal https://t.co/6KFinSEFUt
#
# Posted by:
# Nellaivijayfc
#
# Replies to the tweet:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-c589856c4490> in <module>
#      30     for trend in value['trends']:
#      31         if isEnglish(trend['name']):
# ---> 32             myStream.filter(track=[trend['name']],languages=['en'])
#
# ~/.local/lib/python3.6/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~/.local/lib/python3.6/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~/.local/lib/python3.6/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~/.local/lib/python3.6/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     349             next_status_obj = buf.read_len(length)
#     350             if self.running and next_status_obj:
# --> 351                 self._data(next_status_obj)
#     352
#     353             # # Note: keep-alive newlines might be inserted before each length value.
#
# ~/.local/lib/python3.6/site-packages/tweepy/streaming.py in _data(self, data)
#     321
#     322     def _data(self, data):
# --> 323         if self.listener.on_data(data) is False:
#     324             self.running = False
#     325
#
# ~/.local/lib/python3.6/site-packages/tweepy/streaming.py in on_data(self, raw_data)
#      52         if 'in_reply_to_status_id' in data:
#      53             status = Status.parse(self.api, data)
# ---> 54             if self.on_status(status) is False:
#      55                 return False
#      56         elif 'delete' in data:
#
# <ipython-input-16-c589856c4490> in on_status(self, status)
#      17         replies = tweepy.Cursor(api.search,q="@"+poster, since_id=tweet_id).items(25)
#      18         count = 0
# ---> 19         for reply in replies:
#      20             if(reply.in_reply_to_status_id == tweet_id):
#      21                 print(reply.text)
#
# ~/.local/lib/python3.6/site-packages/tweepy/cursor.py in __next__(self)
#      47
#      48     def __next__(self):
# ---> 49         return self.next()
#      50
#      51     def next(self):
#
# ~/.local/lib/python3.6/site-packages/tweepy/cursor.py in next(self)
#     217         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     218             # Reached end of current page, get the next page...
# --> 219             self.current_page = self.page_iterator.next()
#     220             while len(self.current_page) == 0:
#     221                 self.current_page = self.page_iterator.next()
#
# ~/.local/lib/python3.6/site-packages/tweepy/cursor.py in next(self)
#     128
#     129         if self.index >= len(self.results) - 1:
# --> 130             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     131
#     132             if hasattr(self.method, '__self__'):
#
# ~/.local/lib/python3.6/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     250                 return method
#     251             else:
# --> 252                 return method.execute()
#     253         finally:
#     254             method.session.close()
#
# ~/.local/lib/python3.6/site-packages/tweepy/binder.py in execute(self)
#     188                                                 timeout=self.api.timeout,
#     189                                                 auth=auth,
# --> 190                                                 proxies=self.api.proxy)
#     191                 except Exception as e:
#     192                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#
# ~/.local/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/.local/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/.local/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     704                 body=body,
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#     708
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/.local/lib/python3.6/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# /usr/lib/python3.6/http/client.py in getresponse(self)
#    1371         try:
#    1372             try:
# -> 1373                 response.begin()
#    1374             except ConnectionError:
#    1375                 self.close()
#
# /usr/lib/python3.6/http/client.py in begin(self)
#     309         # read until we get a non-100 response
#     310         while True:
# --> 311             version, status, reason = self._read_status()
#     312             if status != CONTINUE:
#     313                 break
#
# /usr/lib/python3.6/http/client.py in _read_status(self)
#     270
#     271     def _read_status(self):
# --> 272         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     273         if len(line) > _MAXLINE:
#     274             raise LineTooLong("status line")
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /usr/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import sys
import json
import time
import logging
import twitter
import urllib.parse

from os import environ as e

t = twitter.Api(
    consumer_key="ac8YRucGrIbNHUcD2IYqpfp4s",
    consumer_secret='ymifAZlIIJAVDqGfxcrVcmPCiEXYhxRUqyh43KVvyxmuuYG2s3',
    access_token_key='1033620667155984384-uKKn6iHzAan304XrH5nU8evIQJUwak',
    access_token_secret='6TcRuKZE4EGx5F2XTCavopZdttlw380Ms8MoyyMqZqiS2',
    sleep_on_rate_limit=True
)

def tweet_url(t):
    return "https://twitter.com/%s/status/%s" % (t.user.screen_name, t.id)

def get_replies():
    user = 'patrick_oshag'
    tweet_id = '1101551802930077696'
    max_id = None
    logging.info("looking for replies to: %s" % tweet_url(tweet))
    while True:
        q = urllib.parse.urlencode({"q": "to:%s" % user})
        try:
            replies = t.GetSearch(raw_query=q, since_id=tweet_id, max_id=max_id, count=20)
        except twitter.error.TwitterError as e:
            logging.error("caught twitter api error: %s", e)
            time.sleep(60)
            continue
        for reply in replies:
            logging.info("examining: %s" % tweet_url(reply))
            if reply.in_reply_to_status_id == tweet_id:
                logging.info("found reply: %s" % tweet_url(reply))
                yield reply
                # recursive magic to also get the replies to this reply
                for reply_to_reply in get_replies(reply):
                    yield reply_to_reply
            max_id = reply.id
        if len(replies) != 100:
            break
            
for reply in get_replies():
    print(reply.AsJsonString())

# %%
def get_twitter_url(user_name, status_id):
    return "https://twitter.com/" + str(user_name) + "/status/" + str(status_id)

url = get_twitter_url('afcjxmes', '1342501313771397121')
print(url)
