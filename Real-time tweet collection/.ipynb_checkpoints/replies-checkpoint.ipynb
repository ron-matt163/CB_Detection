# %%
import tweepy 
import sys
# Fill the X's with the credentials obtained by  
# following the above mentioned procedure. 
auth = tweepy.OAuthHandler('ac8YRucGrIbNHUcD2IYqpfp4s', 'ymifAZlIIJAVDqGfxcrVcmPCiEXYhxRUqyh43KVvyxmuuYG2s3')
auth.set_access_token('1033620667155984384-uKKn6iHzAan304XrH5nU8evIQJUwak', '6TcRuKZE4EGx5F2XTCavopZdttlw380Ms8MoyyMqZqiS2')
api = tweepy.API(auth, wait_on_rate_limit=True)

public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# @FPL_physio GW29
# That scarf. 🔥🔥🔥 https://t.co/tBJ2ZFbc5u
# John Stones, welcome to Editor F.C.
#
# Now, keep the bench warm. Mitchell starts 😏
# I have evolved passed the need for alcohol... I'll shot to that
# The Liverpool fullbacks are gonna smash it in 2021
#
# #FPL #FPLCommunity https://t.co/5bS0UXeRIr
# I said i was gonna get dressed up and put on makeup for New Years. Lololololol
# @FPLGeneral Happy New year Mark!
# @EddieLongbridg3 Mikel arteta is too good!!!!! Arsenal coming for title charge for sure for sure
#
# Invest in arteta stocks IMMEDIATELY 🤯
# RT @Lovatic5HDores7: Just letting y’all know the best way to end the year is to watch @jessamynduke @OKAYGAM3R CHOPMANIA NYE STREAM 2017 ht…
# TAA? 🙄
#
# RECOUNT!
#
# 1000s of fraudulent ballet boxes arrived overnight @OfficialFPL headquarters!
#
# #FPLCommunity has… https://t.co/BZxA2AO2X8
# I mean @MarthaStewart is here...
#
# So everybody needs to show up!
#
# Excited for the world to also get a sneak peek a… https://t.co/99avsbRQQW
# RT @WengerDein: Time zones are cool
#
# England is in 2021
#
# Australia is in 2021
#
# USA is in 2020
#
# Tottenham fans are in 2008
# Happy New Year to everyone out there! May this year be filled with love, peace, hope and more importantly - green a… https://t.co/baPNbxla45
# TONIGHT 11et / 8pt 🍾
#
# ⏰ https://t.co/T37IDdtPYW
# #FPL Overnight Fallers:
# Trossard (£5.7M)
# Poveda-Ocampo (£4.3M)
# Basham (£4.6M)
# Diangana (£5.1M)
# Krovinovic (£4.9M)
# M… https://t.co/pNABlkOygz
# #FPL Overnight Rises:
# Mina (£5.6M)
# Bamford (£6.6M)
# Robertson (£7.4M)
# Alexander-Arnold (£7.3M)
# Cancelo (£5.7M)
# Bednarek (£4.9M)
# I just got my smell/taste back!!! i am the happiest
# Can anyone in the #FPLCommunity match this? 🤤
#
# Officially a whiskey drinker now 😎 https://t.co/I85hNJ6Ts5
# Sharing this song with you all on the final night of 2020. It’s one of my absolute favorites. I hope it makes you a… https://t.co/a8mahVRW4l
# Man Utd have lost just three of their 29 #PL matches since @B_Fernandes8 made his debut at the start of February 20… https://t.co/Qf46X3C5WR

# %%
import tweepy
import os
import json
import sys
import geocoder
from langdetect import detect

def isEnglish(s):
    try:
        s.encode(encoding='utf-8').decode('ascii')
    except UnicodeDecodeError:
        return False
    else:
        return True

# API Keys and Tokens

# Authorization and Authentication

date_since="2020-12-01"

if __name__ == "__main__":
    # Available Locations
    available_loc = api.trends_available()
    # writing a JSON file that has the available trends around the world
    with open("available_locs_for_trend.json","w") as wp:
        wp.write(json.dumps(available_loc, indent=1))

    # Trends for Specific Country     # location as argument variable 
    g = geocoder.osm('India') # getting object that has location's latitude and longitude

    closest_loc = api.trends_closest(g.lat, g.lng)
    trends = api.trends_place(closest_loc[0]['woeid'],count=200,lang="en")
    # writing a JSON file that has the latest trends for that location
    print("The top trends for the location are :") 
    for value in trends: 
        for trend in value['trends']:
            if isEnglish(trend['name']):
                print(trend['name'])
# Out:
# The top trends for the location are :
# #BiggestRevelationOf2021
# Happy New Year
# The Messiah
# #PiousIncarnationMonth
# #Welcome2021
# #Happy2021
# Wishing
# MF DOOM
# Same 2
# Hope 2021
# Aapko
# Dear 2021
# #Hello2021
# #2021year
# #GoodBye2020
# #BirthMonthOfShahSatnamJi
# #2021makeawish
# #newbeginnings
# #Animal
# #BigPrediction_2021
# #BhimaKoregaon
# #MKStalinFor2021
# #2021WithRadheShyam
# #RanbirKapoor
# #HNY2021
# #2021NYEL
# #harrylouyear
# #1McmtsForBebbuliBheemIntro
# #RestoreTheSnyderVerse

# %%
import re
import string
import stopwords
import nltk # Natural Language tool kit 
nltk.download('stopwords')
from nltk.corpus import stopwords
def message_cleaning(message):
    message = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",message).split())
    Test_punc_removed = [char for char in message if char not in string.punctuation]
    Test_punc_removed_join = ''.join(Test_punc_removed)
    Test_punc_removed_join_clean = [word.lower() for word in Test_punc_removed_join.split() if word.lower() not in stopwords.words('english')]
    print(Test_punc_removed_join_clean)
# Out:
# /home/pavan/snap/jupyter/common/lib/python3.7/site-packages/joblib/_multiprocessing_helpers.py:45: UserWarning: [Errno 13] Permission denied.  joblib will operate in serial mode
#   warnings.warn('%s.  joblib will operate in serial mode' % (e,))
# [nltk_data] Error loading stopwords: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1056)>

# %%
count = 0
for value in trends: 
    for trend in value['trends']:
        if isEnglish(trend['name']): 
            print(trend['name'])
            tweets = tweepy.Cursor(api.search, q=trend['name'],lang="en", since=date_since,result_type='popular', timeout=999999).items(10)
            for tweet in tweets:
                print("Tweet:\n")
                print(tweet.text)
                tweet_id = tweet.id
                print("Tweet ID: " + str(tweet_id))
                poster = tweet.user.screen_name
                print("\nPoster: " + poster + "\n")
                print("Replies to this tweet: \n")
                replies = tweepy.Cursor(api.search,q="@"+poster, since_id=tweet_id).items(1000)
                #print(type(replies))
                count = 0
                for reply in replies:
                    if(reply.in_reply_to_status_id == tweet_id):
                        print(reply.text)
                        count +=1
                    if count==50:
                        break                
            count +=1
        if count==5:
            break
# Out:
# #BoxingDayTest
# Tweet:
#
# 🇮🇳 bounce back in style 😎
#
# An all-round performance and a superb finish by @RealShubmanGill helped #TeamIndia level… https://t.co/JU4g3Ag7hG
# Tweet ID: 1343779593228939265
#
# Poster: KKRiders
#
# Replies to this tweet:
#
# @KKRiders @RealShubmanGill #ShubmanGill another innings filled with classy &amp; praiseworthy shots.
# @KKRiders @RealShubmanGill Well Played #TeamIndia
# #INDvsAUS
# @KKRiders @RealShubmanGill Next big thing in Indian cricket team is SHUBMAN GILL .
# @KKRiders @RealShubmanGill Very big big win for the indian Team.all round petformence
# @KKRiders @RealShubmanGill All the Indian bowlers did their efforts best... Hats off 😊👍
# @KKRiders @RealShubmanGill 😌😌.. https://t.co/mxzfBidcMj
# @KKRiders @RealShubmanGill 👍
# @KKRiders @RealShubmanGill Shubman Gill and Rahane. Write it correct
# @KKRiders @RealShubmanGill Sukoon Mila 😌
# #shubmangill #AUSvIND https://t.co/gILTzsULjl
# @KKRiders @RealShubmanGill "Bumrah Bumrah" chantings by cutest indian fan.
# 👇👇
# https://t.co/S6r87rKgvJ
# Tweet:
#
# Today India won two of their three #BoxingDayTest matches - 10 years apart!
# 2010: at Durban by 87 runs (Captain: MS… https://t.co/rU0PEyCnj1
# Tweet ID: 1343771508389281792
#
# Poster: mohanstatsman
#
