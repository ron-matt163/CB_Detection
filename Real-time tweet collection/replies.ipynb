# %%
import tweepy 
import sys
# Fill the X's with the credentials obtained by  
# following the above mentioned procedure. 
consumer_key = "0VVJldZQQGC3L61nBwRFwPzQu" 
consumer_secret = "HEGgY2iZ8P8yKNIgcEtmFQEytCL6IswOCI1O1vimpjciPmFPtd"
access_key = "1075785913815445506-tyt6e1UxJ6c4CAQbk5fkqFFDCixA2M"
access_secret = "BvRTNn2OTZ3gkUZT13NuaV1rg3r2QjiERwCUEXpE2S5zc"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key,access_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# Watch the exclusive trailer for The Wanting Mare, a fantasy drama coming to VOD and select theaters on February 5. 🐴 https://t.co/xmPiRHmVNc
# RT @JimmyKimmelLive: Elizabeth Olsen on @Marvel’s #WandaVision, fan theories, and an exclusive never-before-seen clip! https://t.co/wktPPXO…
# An Xbox console experience survey reportedly asked Series X|S owners if they wish their controller had features fou… https://t.co/LFYg0hPKDa
# RT @FenyxRising: Snakes for hair and a petrifying gaze? Join the @Ubisoft News team as they continue their quest in Immortals Fenyx Rising!
# The sword-wielding Lady Shiva, voiced by Kelly Hu, makes her entrance in this exclusive clip from Batman: Soul of t… https://t.co/vdbPVpVwpf
# Let’s fight for it 💥 Marvel Studios’ #WandaVision starts streaming Jan. 15 on @DisneyPlus. https://t.co/3AMENrdNme
# RT @EASPORTSFIFA: It’s almost time.
# 7 January
# #TOTY #Vote #FIFA21 #FUT https://t.co/fJ19CvR50P
# Hawkeye will premiere on Disney+ in 2021. If you're not familiar with Hailee Steinfeld's new character Kate Bishop,… https://t.co/9nxalGOPZX
# RT @RCARecords: GIVE @brckhmptn SOME "SUGAR" FOR BEING RIAA PLATINUM CERTIFIED🧡 🔗: https://t.co/iuRz1YnYRj https://t.co/d1oKdA8B2C
# Outriders has been delayed to April 1, but a demo featuring all four classes will be made available in late Februar… https://t.co/NY1O5mhBRm
# RT @MSFTIssues: Fasten your seat belts. 💺 Microsoft has partnered with @AlaskaAir to reduce its employee’s in-flight carbon impact.
#
# Here’…
# The third Coin King Special Battle is coming to #SuperMarioBros35 this weekend! Tackle a random first course mixed… https://t.co/EtwEPqHv2v
# RT @wandavision: Get to know the cast of #WandaVision, Marvel Studios' first series on @DisneyPlus. Reply to this tweet with a question for…
# If you’re new to GTA Online and looking for a few tips on how to begin building your criminal empire, we’ve rounded… https://t.co/7mWQLuoPFl
# Mythic wallpapers 💫
#
# 📸 @G_Assassin90 | @VGphotoMode https://t.co/H6w23JkD9M
# Check out the exclusive trailer debut for The Wanting Mare, the first fantasy film release of 2021:… https://t.co/YYMDpLAx0w
# Or try telling the truth:​
# Out of Office… just kidding. I’m at home.
# Sorry I missed you. Currently making my living room into the perfect beach getaway after taking my holiday decorati… https://t.co/unllkv2Sp7
# I’ll be OOO on 1/6 for a gift-wrapping event (yes, gift wrapping season is over but it's never a bad time to wrap u… https://t.co/wLrA465sDi

# %%
import tweepy
import os
import json
import sys
import geocoder
from langdetect import detect

def isEnglish(s):
    try:
        s.encode(encoding='utf-8').decode('ascii')
    except UnicodeDecodeError:
        return False
    else:
        return True

# API Keys and Tokens

# Authorization and Authentication

date_since="2020-12-01"

if __name__ == "__main__":
    # Available Locations
    available_loc = api.trends_available()
    # writing a JSON file that has the available trends around the world
    with open("available_locs_for_trend.json","w") as wp:
        wp.write(json.dumps(available_loc, indent=1))

    # Trends for Specific Country     # location as argument variable 
    g = geocoder.osm('India') # getting object that has location's latitude and longitude

    closest_loc = api.trends_closest(g.lat, g.lng)
    trends = api.trends_place(closest_loc[0]['woeid'],count=200,lang="en")
    # writing a JSON file that has the latest trends for that location
    print("The top trends for the location are :") 
    for value in trends: 
        for trend in value['trends']:
            if isEnglish(trend['name']):
                print(trend['name'])
# Out:
# The top trends for the location are :
# #MudinjaaThodaSolraPaapom
# #MasterPromo2
# #HappyBirthdayKhalistaniKutte
# RAMARAJU RAMPAGE CONTINUES
# Ministry of Home Affairs
# Ozil
# Happy Birthday Sir
# Bharat Ratna
# TN Govt
# Rourkela Steel Plant
# Thalapathy
# Matic
# Abdul
# Mayank
# Saini
# brendon urie
# Natarajan
# Sonia
# Safari
# Kanye
# Buy Now
# Register Now
# vihari
# Levi
# Senate
# #PenaliseSSRKillers
# #AskDK
# #MasterRaid
# #26JanDelhiTractorParade
# #YashBossBDayCDP
# #VakeelSaabRecords
# #ThankYouCarles
# #KGF2on8thJan
# #SaveAndhraTemples
# #SaveBirds
# #PunjabKiShaanDiljit
# #Badaun
# #HappyBirthdayDiljitDosanjh
# #HappyBirthdayARRahman
# #Acharya
# #SocialJusticeHero_DrThiruma
# #ShadesTwitter
# #wednesdaythought

# %%
import re
from nltk.stem import WordNetLemmatizer
import string
import nltk
from nltk.corpus import stopwords


def message_cleaning(message):
    message = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",message).split())
    Test_punc_removed = [char for char in message if char not in string.punctuation]
    Test_punc_removed_join = ''.join(Test_punc_removed)
    Test_punc_removed_join_clean = [word.lower() for word in Test_punc_removed_join.split() if word.lower() not in stopwords.words('english')]
    wordnet_lemmatizer = WordNetLemmatizer()
    lemma_list = [wordnet_lemmatizer.lemmatize(word) for word in Test_punc_removed_join_clean]
    
    return lemma_list

# %%
count = 0
for value in trends: 
    for trend in value['trends']:
        if isEnglish(trend['name']): 
            print(trend['name'])
            tweets = tweepy.Cursor(api.search, q=trend['name'],lang="en", since=date_since,result_type='popular', timeout=999999).items(10)
            for tweet in tweets:
                print("Tweet:\n")
                cleaned_tweet = message_cleaning(tweet.text)
                print(cleaned_tweet)
                tweet_id = tweet.id
                print("Tweet ID: " + str(tweet_id))
                poster = tweet.user.screen_name
                print("\nPoster: " + poster + "\n")
                print("Replies to this tweet: \n")
                replies = tweepy.Cursor(api.search,q="@"+poster, since_id=tweet_id).items(50)
                #print(type(replies))
                count = 0
                for reply in replies:
                    if(reply.in_reply_to_status_id == tweet_id):
                        cleaned_reply = message_cleaning(reply.text)
                        print(cleaned_reply)
                        count +=1
                    if count==10:
                        break                
            count +=1
        if count==5:
            break
# Out:
# #MudinjaaThodaSolraPaapom
# #MasterPromo2
# Tweet:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-836a712aaf60> in <module>
#       7             for tweet in tweets:
#       8                 print("Tweet:\n")
# ----> 9                 cleaned_tweet = message_cleaning(tweet.text)
#      10                 print(cleaned_tweet)
#      11                 tweet_id = tweet.id
#
# <ipython-input-3-e8ac2b782c8e> in message_cleaning(message)
#       4 def message_cleaning(message):
#       5     message = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",message).split())
# ----> 6     Test_punc_removed = [char for char in message if char not in string.punctuation]
#       7     Test_punc_removed_join = ''.join(Test_punc_removed)
#       8     Test_punc_removed_join_clean = [word.lower() for word in Test_punc_removed_join.split() if word.lower() not in stopwords.words('english')]
#
# <ipython-input-3-e8ac2b782c8e> in <listcomp>(.0)
#       4 def message_cleaning(message):
#       5     message = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",message).split())
# ----> 6     Test_punc_removed = [char for char in message if char not in string.punctuation]
#       7     Test_punc_removed_join = ''.join(Test_punc_removed)
#       8     Test_punc_removed_join_clean = [word.lower() for word in Test_punc_removed_join.split() if word.lower() not in stopwords.words('english')]
#
# NameError: name 'string' is not defined

# %% [markdown]
# # Classifying live tweets from trending topics

# %%
import pickle
with open('../Count vectorizer feature extraction/NBBoWTrained.sav', 'rb') as f:
    loaded_NB_classifier,loaded_func_countvectorizer = pickle.load(f)

# %%
count = 0
tweet_count = 0
bully_count = 0
for value in trends: 
    for trend in value['trends']:
        if isEnglish(trend['name']): 
            print(trend['name'])
            tweets = tweepy.Cursor(api.search, q=trend['name'],lang="en", since=date_since,result_type='popular', timeout=999999).items(10)
            for tweet in tweets:
                print("Tweet:\n")
                cleaned_tweet = message_cleaning(tweet.text)
                print(cleaned_tweet)
                tweet_id = tweet.id
                print("Tweet ID: " + str(tweet_id))
                poster = tweet.user.screen_name
                print("\nPoster: " + poster + "\n")
                print("Replies to this tweet: \n")
                replies = tweepy.Cursor(api.search,q="@"+poster, since_id=tweet_id).items(1000)
                #print(type(replies))
                count = 0
                for reply in replies:
                    if(reply.in_reply_to_status_id == tweet_id):
                        tweet_count += 1
                        input_text = []
                        input_text.append(reply.text)
                        print(input_text)
                        input_vector = loaded_func_countvectorizer.transform(input_text)
                        result = loaded_NB_classifier.predict(input_vector)
                        print("\nClassification:\n")
                        print(result)
                        if(result[0]):
                            bully_count += 1
                    if count==10:
                        break                
            count +=1
        if count==5:
            break
# Out:
# #MudinjaaThodaSolraPaapom
# #MasterPromo2
# Tweet:
#
# ['mudinjaa', 'thoda', 'solraa', 'paapom', 'vaathi', 'voice', 'finally', 'happy', 'ah', 'nanba', 'master', 'masterpromo2']
# Tweet ID: 1346796068692926467
#
# Poster: XBFilmCreators
#
# Replies to this tweet:
#
# ['@XBFilmCreators @actorvijay @VijaySethuOffl @Dir_Lokesh @MalavikaM_ @anirudhofficial @imKBRshanthnu… https://t.co/DAa74JAWEP']
#
# Classification:
#
# [0]
# ['@XBFilmCreators @actorvijay @VijaySethuOffl @Dir_Lokesh @MalavikaM_ @anirudhofficial @imKBRshanthnu… https://t.co/fTX4IFoVwy']
#
# Classification:
#
# [0]
# ['@XBFilmCreators @actorvijay @VijaySethuOffl @Dir_Lokesh @MalavikaM_ @anirudhofficial @imKBRshanthnu… https://t.co/9SdR6fRZnC']
#
# Classification:
#
# [0]
# ['@XBFilmCreators @actorvijay @VijaySethuOffl @Dir_Lokesh @MalavikaM_ @anirudhofficial @imKBRshanthnu… https://t.co/ym28W2mt3W']
#
# Classification:
#
# [0]
# ['@XBFilmCreators @actorvijay @VijaySethuOffl @Dir_Lokesh @MalavikaM_ @anirudhofficial @imKBRshanthnu… https://t.co/zRcWypmjQa']
#
# Classification:
#
# [0]
# ['@XBFilmCreators @actorvijay @VijaySethuOffl @Dir_Lokesh @MalavikaM_ @anirudhofficial @imKBRshanthnu… https://t.co/ycoXOA0cvk']
#
# Classification:
#
# [0]
# ['@XBFilmCreators @actorvijay @VijaySethuOffl @Dir_Lokesh @MalavikaM_ @anirudhofficial @imKBRshanthnu… https://t.co/c3X9c87prD']
#
# Classification:
#
# [0]
# ['@XBFilmCreators @actorvijay @VijaySethuOffl @Dir_Lokesh @MalavikaM_ @anirudhofficial @imKBRshanthnu… https://t.co/u8s0tJzL4l']
#
# Classification:
#
# [0]
# ['@XBFilmCreators @actorvijay @VijaySethuOffl @Dir_Lokesh @MalavikaM_ @anirudhofficial @imKBRshanthnu… https://t.co/F8q4J30KIj']
#
# Classification:
#
# [0]
# ['@XBFilmCreators @actorvijay @VijaySethuOffl @Dir_Lokesh @MalavikaM_ @anirudhofficial @imKBRshanthnu… https://t.co/TzUPsPgnk5']
#
# Classification:
#
# [0]
# ['@XBFilmCreators @actorvijay @VijaySethuOffl @Dir_Lokesh @MalavikaM_ @anirudhofficial @imKBRshanthnu… https://t.co/LIMZaJScTL']
#
# Classification:
#
# [0]
# ['@XBFilmCreators @actorvijay @VijaySethuOffl @Dir_Lokesh @MalavikaM_ @anirudhofficial @imKBRshanthnu… https://t.co/tc80Wpmesi']
#
# Classification:
#
# [0]
# ['@XBFilmCreators @actorvijay @VijaySethuOffl @Dir_Lokesh @MalavikaM_ @anirudhofficial @imKBRshanthnu… https://t.co/pls35AiObO']
#
# Classification:
#
# [0]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-09e4263aa8a5> in <module>
#      17                 #print(type(replies))
#      18                 count = 0
# ---> 19                 for reply in replies:
#      20                     if(reply.in_reply_to_status_id == tweet_id):
#      21                         input_text = []
#
# ~/.local/lib/python3.6/site-packages/tweepy/cursor.py in __next__(self)
#      47
#      48     def __next__(self):
# ---> 49         return self.next()
#      50
#      51     def next(self):
#
# ~/.local/lib/python3.6/site-packages/tweepy/cursor.py in next(self)
#     217         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     218             # Reached end of current page, get the next page...
# --> 219             self.current_page = self.page_iterator.next()
#     220             while len(self.current_page) == 0:
#     221                 self.current_page = self.page_iterator.next()
#
# ~/.local/lib/python3.6/site-packages/tweepy/cursor.py in next(self)
#     128
#     129         if self.index >= len(self.results) - 1:
# --> 130             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     131
#     132             if hasattr(self.method, '__self__'):
#
# ~/.local/lib/python3.6/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     250                 return method
#     251             else:
# --> 252                 return method.execute()
#     253         finally:
#     254             method.session.close()
#
# ~/.local/lib/python3.6/site-packages/tweepy/binder.py in execute(self)
#     188                                                 timeout=self.api.timeout,
#     189                                                 auth=auth,
# --> 190                                                 proxies=self.api.proxy)
#     191                 except Exception as e:
#     192                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#
# ~/.local/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/.local/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/.local/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     704                 body=body,
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#     708
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/.local/lib/python3.6/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# /usr/lib/python3.6/http/client.py in getresponse(self)
#    1371         try:
#    1372             try:
# -> 1373                 response.begin()
#    1374             except ConnectionError:
#    1375                 self.close()
#
# /usr/lib/python3.6/http/client.py in begin(self)
#     309         # read until we get a non-100 response
#     310         while True:
# --> 311             version, status, reason = self._read_status()
#     312             if status != CONTINUE:
#     313                 break
#
# /usr/lib/python3.6/http/client.py in _read_status(self)
#     270
#     271     def _read_status(self):
# --> 272         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     273         if len(line) > _MAXLINE:
#     274             raise LineTooLong("status line")
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /usr/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# # Classifying live tweets given a search keyword

# %%
print("\nEnter the search keyword: ")
query = input()
# Out:
# Enter the search keyword:
# messi

# %%
tweet_count = 0
bully_count = 0
bully_record = []


tweets = tweepy.Cursor(api.search, q=query,lang="en", since=date_since,result_type='popular', timeout=999999).items(10)
for tweet in tweets:
    print("Tweet:\n")
    cleaned_tweet = message_cleaning(tweet.text)
    print(cleaned_tweet)
    tweet_id = tweet.id
    print("Tweet ID: " + str(tweet_id))
    poster = tweet.user.screen_name
    print("\nPoster: " + poster + "\n")
    print("Replies to this tweet: \n")
    replies = tweepy.Cursor(api.search,q="@"+poster, since_id=tweet_id).items(1000)
    #print(type(replies))
    count = 0
    for reply in replies:
        if(reply.in_reply_to_status_id == tweet_id):
            tweet_count += 1
            input_text = []
            input_text.append(reply.text)
            print(input_text)
            input_vector = loaded_func_countvectorizer.transform(input_text)
            result = loaded_NB_classifier.predict(input_vector)
            print("\nClassification:\n")
            print(result)
            if(result[0]):
                bully_row = []
                bully_count += 1
                bully_row.append(reply.user.screen_name)
                bully_row.append(poster)
                bully_row.append(reply.text)
                bully_record.append(bully_row)
        if count==10:
            break
# Out:
# Tweet:
#
# ['really', 'different', 'planet', 'messi', 'masterclass', 'bayern', '2015', 'ucl']
# Tweet ID: 1346883277928464384
#
# Poster: ChampionsLeague
#
# Replies to this tweet:
#
# ['@ChampionsLeague @FCBarcelona Su última champions del Barcelona, cuando Messi estaba bien acompañado como jugadores… https://t.co/cQ0A64Yult']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona My Goat']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona @VD_draker enjoy.']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona 😂😂😂😂😂😂\n😂                     😂\n😂                     😂\n😂                     😂\n😂… https://t.co/YIZW8z1JBj']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona and 5 years later ... 8 - 2 !!!']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona 8-2😅']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona As much as it hurt, Messi’s first goal was easily one of the nicest goal I’ve seen li… https://t.co/r0KU5dOE8C']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona Barca this Bayern that, here’s the biggest club in the world https://t.co/Ree33ngX1K']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona Ahhh pero en 2020!!!']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona no  comment  ?? https://t.co/9ElNu0ky20']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona https://t.co/0vFAgxMrUW']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona https://t.co/srPOz4azQP']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona no  comment https://t.co/Hby9N5BxWd']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona ❤️🤤']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona https://t.co/T2my9TcD06']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona Five years later.... 8:2']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona The G.O.A.T']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona @SendMeThisVideo /t']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona There is an issue with this handle with Barca and messi, so many teams and players si… https://t.co/wsyFAbHOX0']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona Ese año el @FCBayern tenía muchas bajas. \nPorque no ponen su actuación en 2013 o 2020 🤔']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona 8-2']
#
# Classification:
#
# [0]
# ["@ChampionsLeague @FCBarcelona Well the teacher got his ass whipped in 2020 didn't he now"]
#
# Classification:
#
# [1]
# ['@ChampionsLeague @FCBarcelona Yup he is https://t.co/isIKTHNaEQ']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona 🙄🤣🤣 https://t.co/kpjaFx36x4']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona @Ferro25Richard']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona He is finished... Period..Better go to his childhood club in Argentina']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona No VAR and Messi in his prime. Those were the days 😍']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona 8']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona That first goal\n\nWhy did the guy go to ground 🤣🤣🔥']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona 🐐']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona Beyond Human']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona ااااه. https://t.co/QppCYO9Dy1']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona Classical']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona Thennn he disappears and lose 8-2 https://t.co/RNumMDFgB5']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona Really now? We just have to go and dig things from 7 years ago! Let’s accept the fact… https://t.co/Inb8zCV9Y9']
#
# Classification:
#
# [0]
# ["@ChampionsLeague @FCBarcelona @olonaidrees enjoy what your Goat can't give you"]
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona These football threads sum up twitter so well, someone posts some unbelievable skills… https://t.co/5Bx0OPa7s5']
#
# Classification:
#
# [1]
# ['@ChampionsLeague @FCBarcelona https://t.co/DluYCTmFTx']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona And now 8-2']
#
# Classification:
#
# [0]
# ["@ChampionsLeague @FCBarcelona I'll never get tired of watching his greatness"]
#
# Classification:
#
# [1]
# ['@ChampionsLeague @FCBarcelona من حقكم ان تنسوا و من واجبنا أن نذكركم https://t.co/6glfMzkx1C']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona Once in a generation player']
#
# Classification:
#
# [0]
# ["@ChampionsLeague @FCBarcelona Things I've learnt so far:\n-Pessi is finished\n-Barca are finishing 15th\n-Ronaldo is b… https://t.co/JDjG3N4Hb6"]
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona See the type of goals Suarez was missing smh 🤦🏽\u200d♂️']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona What happened against Bayern in 2020, Liverpool in 2019, Roma in 2018, Juventus in 2017?']
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona It’s about to get MESSI!!']
#
# Classification:
#
# [0]
# ["@ChampionsLeague @FCBarcelona what's with the 5 referees?"]
#
# Classification:
#
# [0]
# ['@ChampionsLeague @FCBarcelona @GetVideoBot']
#
# Classification:
#
# [0]
# Tweet:
#
# ['lionel', 'messi', 'leaf', 'barcelona', 'end', 'season']
# Tweet ID: 1346442474315722753
#
# Poster: RoyNemer
#
# Replies to this tweet:
#
# ['@RoyNemer https://t.co/HNv9Q4UBM9\nwatch and subscribe']
#
# Classification:
#
# [1]
# ["@RoyNemer I grew up in messi. For messi, i will be the best step he can take. With Barcelona he won't achieve anything- that's the turn"]
#
# Classification:
#
# [0]
# ['@RoyNemer @Iateraljorge que triste 😂😂😂😂😂']
#
# Classification:
#
# [0]
# ["@RoyNemer I've left Barcelona, I am just waiting for him at the next club he decides to join."]
#
# Classification:
#
# [0]
# ['@RoyNemer The depression']
#
# Classification:
#
# [0]
# ['@RoyNemer I’m leaving with him. What’s there at Barcelona should keep following?']
#
# Classification:
#
# [0]
# ['@RoyNemer Not leaving man']
#
# Classification:
#
# [0]
# ['@RoyNemer Can it be this January??']
#
# Classification:
#
# [0]
# ['@RoyNemer Man city']
#
# Classification:
#
# [0]
# ["@RoyNemer Am a barca fan but he need to leave, let rebuild the team. Right now messi is part of our problem he doesn't mark again"]
#
# Classification:
#
# [0]
# ["@RoyNemer he gonna leave us isn't he"]
#
# Classification:
#
# [1]
# ['@RoyNemer ELYTE GLOBAL NG is Out-sourcing for Applicants for the positions below:\n-Secretary \n-Human Resource Assis… https://t.co/pOGDcKrXam']
#
# Classification:
#
# [0]
# ["@RoyNemer Me too\nBut life's must go on"]
#
# Classification:
#
# [1]
# ['@RoyNemer 😔']
#
# Classification:
#
# [0]
# ['@RoyNemer https://t.co/0Lj75Wzhzy']
#
# Classification:
#
# [0]
# ['@RoyNemer @zenahyaser you? :p']
#
# Classification:
#
# [0]
# ["@RoyNemer Messi won't play football forever, he will leave someday, sooner or later... But Barcelona will continue"]
#
# Classification:
#
# [1]
# ['@RoyNemer 😫😫']
#
# Classification:
#
# [0]
# ['@RoyNemer To city hopefully 🙏🏿🙏🏿']
#
# Classification:
#
# [0]
# ['@RoyNemer Euphoria lmao']
#
# Classification:
#
# [1]
# ['@RoyNemer Lmao']
#
# Classification:
#
# [1]
# ['@RoyNemer I thought Barca fans said Messi owe Barca his life so he can’t leave the club 😂']
#
# Classification:
#
# [1]
# ['@RoyNemer U guys will be shocked if Messi leaves &amp; FCB ascends. If u all played  organised sports competitively, u… https://t.co/GCsiT4zQFp']
#
# Classification:
#
# [1]
# ['@RoyNemer Me too but I just want him to be happy']
#
# Classification:
#
# [0]
# ["@RoyNemer No he won't"]
#
# Classification:
#
# [0]
# ['@RoyNemer @no_ta74478295 Nobody care 😝😝']
#
# Classification:
#
# [0]
# ['@RoyNemer Ironically, that’s how most EPL fans will feel after he joins Man City 😉😎']
#
# Classification:
#
# [0]
# ['@RoyNemer Yes']
#
# Classification:
#
# [0]
# ['@RoyNemer Tch😂']
#
# Classification:
#
# [1]
# ['@RoyNemer For real, no cap']
#
# Classification:
#
# [0]
# ['@RoyNemer No pues no me arruines el día hermano 😒']
#
# Classification:
#
# [0]
# ['@RoyNemer Too soon']
#
# Classification:
#
# [0]
# ['@RoyNemer 😂😂😂']
#
# Classification:
#
# [0]
# ["@RoyNemer Can't wait tho https://t.co/GBXgr4zAz9"]
#
# Classification:
#
# [1]
# ["@RoyNemer Let him go if he doesn't want to stay."]
#
# Classification:
#
# [1]
# ['@RoyNemer @Hamadou23 @iammassir_2nd vai sentir a nossa dor😂😂😂😂😂🤣🤣🤣🤣🤣']
#
# Classification:
#
# [0]
# ['@RoyNemer Same brother, same']
#
# Classification:
#
# [0]
# ['@RoyNemer I love to see this happen. Juicy https://t.co/CIW8nvDhf4']
#
# Classification:
#
# [0]
# ['@RoyNemer It will happen']
#
# Classification:
#
# [0]
# ['@RoyNemer Sad truth 💔💔😭']
#
# Classification:
#
# [1]
# ['@RoyNemer He’s not going anyway guys']
#
# Classification:
#
# [0]
# ['@RoyNemer Relief']
#
# Classification:
#
# [0]
# ['@RoyNemer Eso está por verse, DUDO que se marche 🤷🏻\u200d♂️']
#
# Classification:
#
# [0]
# ["@RoyNemer He won't."]
#
# Classification:
#
# [0]
# ['@RoyNemer I wish he leave that team , they are nolonger serious they will mess up his legendary status']
#
# Classification:
#
# [0]
# ['@RoyNemer If you love Messi, you pray for him to leave Barcelona...']
#
# Classification:
#
# [1]
# ['@RoyNemer He should']
#
# Classification:
#
# [0]
# ['@RoyNemer Nobody pay that salary and Barcelona  is your home.']
#
# Classification:
#
# [1]
# ['@RoyNemer After Messi and Ramos play together at PSG, Ramos will say Messi &gt;&gt;Cristiano and Messi will say Ramos &gt;&gt;P… https://t.co/8kdQntnSsX']
#
# Classification:
#
# [1]
# ['@RoyNemer All ik is if he doesnt leave then his legacy is finished and he is nothing more than a foolish clown']
#
# Classification:
#
# [1]
# ['@RoyNemer Crying out of joy? Damn']
#
# Classification:
#
# [1]
# ['@RoyNemer I heard about Messi and Ramos joining PSG for free . That would be worse. PSG can win UCL in that scenario']
#
# Classification:
#
# [0]
# ['@RoyNemer i doubt he’d leave if the president he like joins,bartomeu fucked with his mind']
#
# Classification:
#
# [1]
# ["@RoyNemer He won't! He will never move out of his comfort zone"]
#
# Classification:
#
# [0]
# ['@RoyNemer https://t.co/rOwMcZ67Gk']
#
# Classification:
#
# [0]
# ['@RoyNemer Alright 👍']
#
# Classification:
#
# [0]
# ['@RoyNemer Todos lloraremos y lamentaremos el fallecimiento de Leo Messi\n\U0001f97a\U0001f97a\U0001f97a\U0001f97a\U0001f97a\U0001f97a\U0001f97a😊 https://t.co/wIwvCDdxyj']
#
# Classification:
#
# [0]
# ['@RoyNemer 😫😫😫😫']
#
# Classification:
#
# [0]
# ['@RoyNemer https://t.co/GZpoC9Yw2o']
#
# Classification:
#
# [0]
# ['@RoyNemer His salary is outrageous, sorry to say']
#
# Classification:
#
# [0]
# ['@RoyNemer And this guy was happy!!']
#
# Classification:
#
# [0]
# ['@RoyNemer Me if he stays']
#
# Classification:
#
# [0]
# ["@RoyNemer He won't."]
#
# Classification:
#
# [0]
# ['@RoyNemer and ramos leaves to @ManCity']
#
# Classification:
#
# [0]
# ["@RoyNemer He won't"]
#
# Classification:
#
# [0]
# Tweet:
#
# ['strike', 'messi', 'en']
# Tweet ID: 1346445046221058048
#
# Poster: FCBarcelona
#
# Replies to this tweet:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-bee4d975e780> in <module>
#      17     #print(type(replies))
#      18     count = 0
# ---> 19     for reply in replies:
#      20         if(reply.in_reply_to_status_id == tweet_id):
#      21             tweet_count += 1
#
# ~/.local/lib/python3.6/site-packages/tweepy/cursor.py in __next__(self)
#      47
#      48     def __next__(self):
# ---> 49         return self.next()
#      50
#      51     def next(self):
#
# ~/.local/lib/python3.6/site-packages/tweepy/cursor.py in next(self)
#     217         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     218             # Reached end of current page, get the next page...
# --> 219             self.current_page = self.page_iterator.next()
#     220             while len(self.current_page) == 0:
#     221                 self.current_page = self.page_iterator.next()
#
# ~/.local/lib/python3.6/site-packages/tweepy/cursor.py in next(self)
#     128
#     129         if self.index >= len(self.results) - 1:
# --> 130             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     131
#     132             if hasattr(self.method, '__self__'):
#
# ~/.local/lib/python3.6/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     250                 return method
#     251             else:
# --> 252                 return method.execute()
#     253         finally:
#     254             method.session.close()
#
# ~/.local/lib/python3.6/site-packages/tweepy/binder.py in execute(self)
#     161                                     if self.wait_on_rate_limit_notify:
#     162                                         log.warning("Rate limit reached. Sleeping for: %d" % sleep_time)
# --> 163                                     time.sleep(sleep_time + 5)  # sleep for few extra sec
#     164
#     165                 # if self.wait_on_rate_limit and self._reset_time is not None and \
#
# KeyboardInterrupt:

# %%
print("Total tweet:" + str(tweet_count))
print("Offensive tweets:" + str(bully_count))
#Offendor,victim and tweet in each record
print(bully_record)
# Out:
# Total tweet:113
# Offensive tweets:21
# [['FartAndTell', 'ChampionsLeague', "@ChampionsLeague @FCBarcelona Well the teacher got his ass whipped in 2020 didn't he now"], ['Awhyex31', 'ChampionsLeague', '@ChampionsLeague @FCBarcelona These football threads sum up twitter so well, someone posts some unbelievable skills… https://t.co/5Bx0OPa7s5'], ['grinchoi', 'ChampionsLeague', "@ChampionsLeague @FCBarcelona I'll never get tired of watching his greatness"], ['pistoleromigo1', 'RoyNemer', '@RoyNemer https://t.co/HNv9Q4UBM9\nwatch and subscribe'], ['Noha24107075', 'RoyNemer', "@RoyNemer he gonna leave us isn't he"], ['KTabahawa', 'RoyNemer', "@RoyNemer Me too\nBut life's must go on"], ['olochenice', 'RoyNemer', "@RoyNemer Messi won't play football forever, he will leave someday, sooner or later... But Barcelona will continue"], ['LowkeyBlocBoy', 'RoyNemer', '@RoyNemer Euphoria lmao'], ['LowkeyBlocBoy', 'RoyNemer', '@RoyNemer Lmao'], ['kennedythacode', 'RoyNemer', '@RoyNemer I thought Barca fans said Messi owe Barca his life so he can’t leave the club 😂'], ['DiKe1KeDi', 'RoyNemer', '@RoyNemer U guys will be shocked if Messi leaves &amp; FCB ascends. If u all played  organised sports competitively, u… https://t.co/GCsiT4zQFp'], ['ezegambaliam', 'RoyNemer', '@RoyNemer Tch😂'], ['TheSkinez', 'RoyNemer', "@RoyNemer Can't wait tho https://t.co/GBXgr4zAz9"], ['Maroof_Hossen', 'RoyNemer', "@RoyNemer Let him go if he doesn't want to stay."], ['Sudipto39826334', 'RoyNemer', '@RoyNemer Sad truth 💔💔😭'], ['nitey1899', 'RoyNemer', '@RoyNemer If you love Messi, you pray for him to leave Barcelona...'], ['rgianott', 'RoyNemer', '@RoyNemer Nobody pay that salary and Barcelona  is your home.'], ['Shayanshafikha1', 'RoyNemer', '@RoyNemer After Messi and Ramos play together at PSG, Ramos will say Messi &gt;&gt;Cristiano and Messi will say Ramos &gt;&gt;P… https://t.co/8kdQntnSsX'], ['PapaVARez', 'RoyNemer', '@RoyNemer All ik is if he doesnt leave then his legacy is finished and he is nothing more than a foolish clown'], ['uzytkownik1510', 'RoyNemer', '@RoyNemer Crying out of joy? Damn'], ['AmirSportss', 'RoyNemer', '@RoyNemer i doubt he’d leave if the president he like joins,bartomeu fucked with his mind']]

# %% [markdown]
# # Trying StreamListener

# %%
import tweepy
#override tweepy.StreamListener to add logic to on_status


class MyStreamListener(tweepy.StreamListener):

    def on_status(self, status):
        if 'RT @' in status.text:
            return
        print("\nTweet:")
        print(status.text)
        print("\nPosted by:")
        poster = status.user.screen_name
        print(poster)
        print("\nReplies to the tweet:")
        tweet_id = status.id
        replies = tweepy.Cursor(api.search,q="@"+poster, since_id=tweet_id).items(25)
        count = 0
        for reply in replies:
            if(reply.in_reply_to_status_id == tweet_id):
                print(reply.text)
                count +=1
            if count==50:
                break                        

myStreamListener = MyStreamListener()
myStream = tweepy.Stream(auth = api.auth, listener=myStreamListener)

for value in trends: 
    for trend in value['trends']:
        if isEnglish(trend['name']):
            myStream.filter(track=[trend['name']],languages=['en'])

# %%
import sys
import json
import time
import logging
import twitter
import urllib.parse

from os import environ as e

t = twitter.Api(
    consumer_key="ac8YRucGrIbNHUcD2IYqpfp4s",
    consumer_secret='ymifAZlIIJAVDqGfxcrVcmPCiEXYhxRUqyh43KVvyxmuuYG2s3',
    access_token_key='1033620667155984384-uKKn6iHzAan304XrH5nU8evIQJUwak',
    access_token_secret='6TcRuKZE4EGx5F2XTCavopZdttlw380Ms8MoyyMqZqiS2',
    sleep_on_rate_limit=True
)

def tweet_url(t):
    return "https://twitter.com/%s/status/%s" % (t.user.screen_name, t.id)

def get_replies():
    user = 'patrick_oshag'
    tweet_id = '1101551802930077696'
    max_id = None
    logging.info("looking for replies to: %s" % tweet_url(tweet))
    while True:
        q = urllib.parse.urlencode({"q": "to:%s" % user})
        try:
            replies = t.GetSearch(raw_query=q, since_id=tweet_id, max_id=max_id, count=20)
        except twitter.error.TwitterError as e:
            logging.error("caught twitter api error: %s", e)
            time.sleep(60)
            continue
        for reply in replies:
            logging.info("examining: %s" % tweet_url(reply))
            if reply.in_reply_to_status_id == tweet_id:
                logging.info("found reply: %s" % tweet_url(reply))
                yield reply
                # recursive magic to also get the replies to this reply
                for reply_to_reply in get_replies(reply):
                    yield reply_to_reply
            max_id = reply.id
        if len(replies) != 100:
            break
            
for reply in get_replies():
    print(reply.AsJsonString())

# %%
def get_twitter_url(user_name, status_id):
    return "https://twitter.com/" + str(user_name) + "/status/" + str(status_id)

url = get_twitter_url('afcjxmes', '1342501313771397121')
print(url)
