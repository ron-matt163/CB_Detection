# %%
import tweepy 
import sys
# Fill the X's with the credentials obtained by  
# following the above mentioned procedure. 
auth = tweepy.OAuthHandler('ac8YRucGrIbNHUcD2IYqpfp4s', 'ymifAZlIIJAVDqGfxcrVcmPCiEXYhxRUqyh43KVvyxmuuYG2s3')
auth.set_access_token('1033620667155984384-uKKn6iHzAan304XrH5nU8evIQJUwak', '6TcRuKZE4EGx5F2XTCavopZdttlw380Ms8MoyyMqZqiS2')
api = tweepy.API(auth, wait_on_rate_limit=True)

public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# @FPL_physio GW29
# That scarf. 🔥🔥🔥 https://t.co/tBJ2ZFbc5u
# John Stones, welcome to Editor F.C.
#
# Now, keep the bench warm. Mitchell starts 😏
# I have evolved passed the need for alcohol... I'll shot to that
# The Liverpool fullbacks are gonna smash it in 2021
#
# #FPL #FPLCommunity https://t.co/5bS0UXeRIr
# I said i was gonna get dressed up and put on makeup for New Years. Lololololol
# @FPLGeneral Happy New year Mark!
# @EddieLongbridg3 Mikel arteta is too good!!!!! Arsenal coming for title charge for sure for sure
#
# Invest in arteta stocks IMMEDIATELY 🤯
# RT @Lovatic5HDores7: Just letting y’all know the best way to end the year is to watch @jessamynduke @OKAYGAM3R CHOPMANIA NYE STREAM 2017 ht…
# TAA? 🙄
#
# RECOUNT!
#
# 1000s of fraudulent ballet boxes arrived overnight @OfficialFPL headquarters!
#
# #FPLCommunity has… https://t.co/BZxA2AO2X8
# I mean @MarthaStewart is here...
#
# So everybody needs to show up!
#
# Excited for the world to also get a sneak peek a… https://t.co/99avsbRQQW
# RT @WengerDein: Time zones are cool
#
# England is in 2021
#
# Australia is in 2021
#
# USA is in 2020
#
# Tottenham fans are in 2008
# Happy New Year to everyone out there! May this year be filled with love, peace, hope and more importantly - green a… https://t.co/baPNbxla45
# TONIGHT 11et / 8pt 🍾
#
# ⏰ https://t.co/T37IDdtPYW
# #FPL Overnight Fallers:
# Trossard (£5.7M)
# Poveda-Ocampo (£4.3M)
# Basham (£4.6M)
# Diangana (£5.1M)
# Krovinovic (£4.9M)
# M… https://t.co/pNABlkOygz
# #FPL Overnight Rises:
# Mina (£5.6M)
# Bamford (£6.6M)
# Robertson (£7.4M)
# Alexander-Arnold (£7.3M)
# Cancelo (£5.7M)
# Bednarek (£4.9M)
# I just got my smell/taste back!!! i am the happiest
# Can anyone in the #FPLCommunity match this? 🤤
#
# Officially a whiskey drinker now 😎 https://t.co/I85hNJ6Ts5
# Sharing this song with you all on the final night of 2020. It’s one of my absolute favorites. I hope it makes you a… https://t.co/a8mahVRW4l
# Man Utd have lost just three of their 29 #PL matches since @B_Fernandes8 made his debut at the start of February 20… https://t.co/Qf46X3C5WR

# %%
import tweepy
import os
import json
import sys
import geocoder
from langdetect import detect

def isEnglish(s):
    try:
        s.encode(encoding='utf-8').decode('ascii')
    except UnicodeDecodeError:
        return False
    else:
        return True

# API Keys and Tokens

# Authorization and Authentication

date_since="2020-12-01"

if __name__ == "__main__":
    # Available Locations
    available_loc = api.trends_available()
    # writing a JSON file that has the available trends around the world
    with open("available_locs_for_trend.json","w") as wp:
        wp.write(json.dumps(available_loc, indent=1))

    # Trends for Specific Country     # location as argument variable 
    g = geocoder.osm('India') # getting object that has location's latitude and longitude

    closest_loc = api.trends_closest(g.lat, g.lng)
    trends = api.trends_place(closest_loc[0]['woeid'],count=200,lang="en")
    # writing a JSON file that has the latest trends for that location
    print("The top trends for the location are :") 
    for value in trends: 
        for trend in value['trends']:
            if isEnglish(trend['name']):
                print(trend['name'])
# Out:
# The top trends for the location are :
# #BiggestRevelationOf2021
# Happy New Year
# The Messiah
# #PiousIncarnationMonth
# #Welcome2021
# #Happy2021
# Wishing
# MF DOOM
# Same 2
# Hope 2021
# Aapko
# Dear 2021
# #Hello2021
# #2021year
# #GoodBye2020
# #BirthMonthOfShahSatnamJi
# #2021makeawish
# #newbeginnings
# #Animal
# #BigPrediction_2021
# #BhimaKoregaon
# #MKStalinFor2021
# #2021WithRadheShyam
# #RanbirKapoor
# #HNY2021
# #2021NYEL
# #harrylouyear
# #1McmtsForBebbuliBheemIntro
# #RestoreTheSnyderVerse

# %%
import re
import string
import stopwords
import nltk # Natural Language tool kit 
nltk.download('stopwords')
from nltk.corpus import stopwords
def message_cleaning(message):
    message = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",message).split())
    Test_punc_removed = [char for char in message if char not in string.punctuation]
    Test_punc_removed_join = ''.join(Test_punc_removed)
    Test_punc_removed_join_clean = [word.lower() for word in Test_punc_removed_join.split() if word.lower() not in stopwords.words('english')]
    print(Test_punc_removed_join_clean)
# Out:
# /home/pavan/snap/jupyter/common/lib/python3.7/site-packages/joblib/_multiprocessing_helpers.py:45: UserWarning: [Errno 13] Permission denied.  joblib will operate in serial mode
#   warnings.warn('%s.  joblib will operate in serial mode' % (e,))
# [nltk_data] Error loading stopwords: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1056)>

# %%
count = 0
for value in trends: 
    for trend in value['trends']:
        if isEnglish(trend['name']): 
            print(trend['name'])
            tweets = tweepy.Cursor(api.search, q=trend['name'],lang="en", since=date_since,result_type='popular', timeout=999999).items(10)
            for tweet in tweets:
                print("Tweet:\n")
                message_cleaning(tweet.text)
                tweet_id = tweet.id
                print("Tweet ID: " + str(tweet_id))
                poster = tweet.user.screen_name
                print("\nPoster: " + poster + "\n")
                print("Replies to this tweet: \n")
                replies = tweepy.Cursor(api.search,q="@"+poster, since_id=tweet_id).items(1000)
                #print(type(replies))
                count = 0
                for reply in replies:
                    if(reply.in_reply_to_status_id == tweet_id):
                        message_cleaning(reply.text)
                        count +=1
                    if count==10:
                        break                
            count +=1
        if count==5:
            break
# Out:
# #BiggestRevelationOf2021
# Happy New Year
# Tweet:
#
# ['happy', 'new', 'year', 'everyone', 'hope', '2021', 'great', 'year', 'keep', 'chasing', 'dreams', 'stay', 'safe', 'ha']
# Tweet ID: 1344676801885384710
#
# Poster: layzhang
#
# Replies to this tweet:
#
# ['happy', 'new', 'year']
# []
# ['awesome', 'dancing', 'lay']
# ['happy', 'new', 'year', 'lay', 'hope', '2021', 'years', 'hope', 'day', 'always', 'filled', 'happiness', 'pos']
# ['uri', 'yixing', 'happy', 'new', 'year', 'u', 'please', 'happy', 'healthy', 'love', 'u']
# ['love', 'lay']
# ['happy', 'new', 'year', 'lay']
# ['happy', 'new', 'year', 'yixing', 'thanks', 'always', 'working', 'hard', 'create', 'masterpiece', 'wait', 'next', 'project']
# ['happy', 'new', 'year', 'ge']
# ['happy', 'new', 'year', 'love']
# Tweet:
#
# ['closing', 'twt', 'happy', 'new', 'year', 'everybody', 'wishing', 'year', 'full', 'happiness', 'new', 'adventures']
# Tweet ID: 1344671336887537665
#
# Poster: Kpop_Herald
#
# Replies to this tweet:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-b2f6ad46e990> in <module>
#      16                 #print(type(replies))
#      17                 count = 0
# ---> 18                 for reply in replies:
#      19                     if(reply.in_reply_to_status_id == tweet_id):
#      20                         message_cleaning(reply.text)
#
# /home/pavan/snap/jupyter/common/lib/python3.7/site-packages/tweepy/cursor.py in __next__(self)
#      47
#      48     def __next__(self):
# ---> 49         return self.next()
#      50
#      51     def next(self):
#
# /home/pavan/snap/jupyter/common/lib/python3.7/site-packages/tweepy/cursor.py in next(self)
#     217         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     218             # Reached end of current page, get the next page...
# --> 219             self.current_page = self.page_iterator.next()
#     220             while len(self.current_page) == 0:
#     221                 self.current_page = self.page_iterator.next()
#
# /home/pavan/snap/jupyter/common/lib/python3.7/site-packages/tweepy/cursor.py in next(self)
#     128
#     129         if self.index >= len(self.results) - 1:
# --> 130             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     131
#     132             if hasattr(self.method, '__self__'):
#
# /home/pavan/snap/jupyter/common/lib/python3.7/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     250                 return method
#     251             else:
# --> 252                 return method.execute()
#     253         finally:
#     254             method.session.close()
#
# /home/pavan/snap/jupyter/common/lib/python3.7/site-packages/tweepy/binder.py in execute(self)
#     188                                                 timeout=self.api.timeout,
#     189                                                 auth=auth,
# --> 190                                                 proxies=self.api.proxy)
#     191                 except Exception as e:
#     192                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#
# /home/pavan/snap/jupyter/common/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /home/pavan/snap/jupyter/common/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     683
#     684         if not stream:
# --> 685             r.content
#     686
#     687         return r
#
# /home/pavan/snap/jupyter/common/lib/python3.7/site-packages/requests/models.py in content(self)
#     827                 self._content = None
#     828             else:
# --> 829                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     830
#     831         self._content_consumed = True
#
# /home/pavan/snap/jupyter/common/lib/python3.7/site-packages/requests/models.py in generate()
#     749             if hasattr(self.raw, 'stream'):
#     750                 try:
# --> 751                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     752                         yield chunk
#     753                 except ProtocolError as e:
#
# /home/pavan/snap/jupyter/common/lib/python3.7/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     573         else:
#     574             while not is_fp_closed(self._fp):
# --> 575                 data = self.read(amt=amt, decode_content=decode_content)
#     576
#     577                 if data:
#
# /home/pavan/snap/jupyter/common/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     516             else:
#     517                 cache_content = False
# --> 518                 data = self._fp.read(amt) if not fp_closed else b""
#     519                 if (
#     520                     amt != 0 and not data
#
# /snap/jupyter/6/lib/python3.7/http/client.py in read(self, amt)
#     445             # Amount is given, implement using readinto
#     446             b = bytearray(amt)
# --> 447             n = self.readinto(b)
#     448             return memoryview(b)[:n].tobytes()
#     449         else:
#
# /snap/jupyter/6/lib/python3.7/http/client.py in readinto(self, b)
#     489         # connection, and the user is reading more bytes than will be provided
#     490         # (for example, reading in 1k chunks)
# --> 491         n = self.fp.readinto(b)
#     492         if not n and b:
#     493             # Ideally, we would raise IncompleteRead if the content-length
#
# /snap/jupyter/6/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /snap/jupyter/6/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1050                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1051                   self.__class__)
# -> 1052             return self.read(nbytes, buffer)
#    1053         else:
#    1054             return super().recv_into(buffer, nbytes, flags)
#
# /snap/jupyter/6/lib/python3.7/ssl.py in read(self, len, buffer)
#     909         try:
#     910             if buffer is not None:
# --> 911                 return self._sslobj.read(len, buffer)
#     912             else:
#     913                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
