# %%
import tweepy 
import sys
# Fill the X's with the credentials obtained by  
# following the above mentioned procedure. 
consumer_key = "ac8YRucGrIbNHUcD2IYqpfp4s" 
consumer_secret = "ymifAZlIIJAVDqGfxcrVcmPCiEXYhxRUqyh43KVvyxmuuYG2s3"
access_key = "1033620667155984384-uKKn6iHzAan304XrH5nU8evIQJUwak"
access_secret = "6TcRuKZE4EGx5F2XTCavopZdttlw380Ms8MoyyMqZqiS2"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key,access_secret)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify = True,retry_count = 5,retry_delay = 5)

public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# Sergio Romero | “Someone is lying to them” – Manchester United player’s wife speaks out about transfer claims.… https://t.co/ev4juKPXFr
# I grew up as a @Fenerbahce fan as a kid in Germany - every German-Turkish person supports a Turkish team when they… https://t.co/Aja70cUmcD
# Surprised not to see Gabriel Jesus in any of the FH teams since Aguero is ruled out
# albert finally bagged https://t.co/RmSGbTCbxR
# @MesutOzil1088 @seadk6 @s04 What about Queen of the South
# ⏰ NEW FPL POST ⏰
#
# The community last minute tips returns for Blank Gameweek 18!
#
# 🤕 Injuries: @BenDinnery
# 🥊 Free Hi… https://t.co/32c2alfevN
# More cancellations to come....
#
# https://t.co/CHH6FALPv2
# Don’t want to steal @seadk6 the show😎 No, to be honest I will always have sympathy for @s04 and I wish them all the… https://t.co/g0PJNTTvvP
# @lateriser12 @zophar666 @BigManBakar Gundo 👀
# The Leeds Lite WC team
#
# #BGW18
# 👤👤👤👤👤👤👤👤👤👤👤
#
# #DGW19 [#Wilson ➡ #Antonio]
# 👤👤👤👤👤👤👤👤👤👤👤👤👤👤👤👤👤👤👤👤👤👤👤👤👤👤👤👤
#
# ...

# %%
import tweepy
import os
import json
import sys
import geocoder
from langdetect import detect

def isEnglish(s):
    try:
        s.encode(encoding='utf-8').decode('ascii')
    except UnicodeDecodeError:
        return False
    else:
        return True

# API Keys and Tokens

# Authorization and Authentication

date_since="2020-12-01"

if __name__ == "__main__":
    # Available Locations
    available_loc = api.trends_available()
    # writing a JSON file that has the available trends around the world
    with open("available_locs_for_trend.json","w") as wp:
        wp.write(json.dumps(available_loc, indent=1))

    # Trends for Specific Country     # location as argument variable 
    g = geocoder.osm('India') # getting object that has location's latitude and longitude

    closest_loc = api.trends_closest(g.lat, g.lng)
    trends = api.trends_place(closest_loc[0]['woeid'],count=200,lang="en")
    # writing a JSON file that has the latest trends for that location
    print("The top trends for the location are :") 
    for value in trends: 
        for trend in value['trends']:
            if isEnglish(trend['name']):
                print(trend['name'])
# Out:
# The top trends for the location are :
# #WeDemandRRRMutualTeaser
# #MasterPromo4
# Shona Shona
# Proud To Be Rashamian
# RAKHI SAWANT WON HEARTS
# Dolphin
# JAB RUBINA MET JYOTIKA
# Signal
# yeonjun
# Vincent Xavier
# BTS vs BTS
# Gill
# Telegram
# QuboolHai First Look Out
# Pujara
# Shashi Tharoor
# eunwoo
# FATF
# soobin
# suho
# Charlie
# #FlipkartForSkillAndExcellence
# #eeswarantrailer
# #JSPwithDivisVictims
# #EkDiyaShaheedonKeNaam
# #MegaHitKGFChapter2Teaser
# #UncoverSSRKillers
# #RheaChakraborty
# #AndhaKannaPaathaakaa
# #KrackFromTomorrow
# #CobraTeaser
# #ShamelessPoster
# #ChiyaanVikram
# #D43ShootBegins
# #KamalVsEPSandStalin
# #Virumaandi
# #HinduRashtra
# #TXT500MonSpotify
# #RecordMakerTXT
# #whatsappprivacypolicy
# #BodyServicingDay
# #KanganaRanaut
# #Dynamite30thWin
# #KGF2TeaserOutNow

# %%
import re
from nltk.stem import WordNetLemmatizer
import string
import nltk
from nltk.corpus import stopwords


def message_cleaning(message):
    message = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",message).split())
    Test_punc_removed = [char for char in message if char not in string.punctuation]
    Test_punc_removed_join = ''.join(Test_punc_removed)
    Test_punc_removed_join_clean = [word.lower() for word in Test_punc_removed_join.split() if word.lower() not in stopwords.words('english')]
    wordnet_lemmatizer = WordNetLemmatizer()
    lemma_list = [wordnet_lemmatizer.lemmatize(word) for word in Test_punc_removed_join_clean]
    
    return lemma_list

# %%
count = 0
tweet_count = 0
bully_count = 0
for value in trends: 
    for trend in value['trends']:
        if isEnglish(trend['name']): 
            print(trend['name'])
            tweets = tweepy.Cursor(api.search, q=trend['name'],lang="en", since=date_since,result_type='popular', timeout=999999).items(10)
            for tweet in tweets:
                print("Tweet:\n")
                cleaned_tweet = message_cleaning(tweet.text)
                print(cleaned_tweet)
                tweet_id = tweet.id
                print("Tweet ID: " + str(tweet_id))
                poster = tweet.user.screen_name
                print("\nPoster: " + poster + "\n")
                print("Replies to this tweet: \n")
                replies = tweepy.Cursor(api.search,q="@"+poster, since_id=tweet_id).items(50)
                #print(type(replies))
                count = 0
                for reply in replies:
                    if(reply.in_reply_to_status_id == tweet_id):
                        cleaned_reply = message_cleaning(reply.text)
                        print(cleaned_reply)
                        count +=1
                    if count==10:
                        break                
            count +=1
        if count==5:
            break
# Out:
# #WeDemandRRRMutualTeaser
# #MasterPromo4
# Tweet:
#
# ['lovely', 'ah', 'romantic', 'ah', 'oru', 'promo', 'way', 'wait', 'till', '6', 'pm', 'masterpromo4', 'master']
# Tweet ID: 1347513419113533440
#
# Poster: XBFilmCreators
#
# Replies to this tweet:
#
# Tweet:
#
# ['sending', 'little', 'snippet', 'love', 'team', 'master', 'today', 'masterpromo4']
# Tweet ID: 1347524647219318787
#
# Poster: MalavikaM_
#
# Replies to this tweet:
#
# Tweet:
#
# ['masterpromo4', 'master', 'maalu', 'time', 'romance', 'watching', 'new', 'pair']
# Tweet ID: 1347521621427326976
#
# Poster: sidhuwrites
#
# Replies to this tweet:
#
# []
# ['master', 'promo', '4', 'telugu', 'version', 'watch']
# Tweet:
#
# ['love', 'mode', 'magical', 'voice', 'lt', '3', 'masterpromo4', 'master', 'masterpongal']
# Tweet ID: 1347522352221810697
#
# Poster: agscinemas
#
# Replies to this tweet:
#
# Tweet:
#
# ['masterpromo4', 'romantic', 'side', 'vaathi', 'ore', 'love', 'feel', 'la', 'irukaru', 'jd', 'andhakannapaathaakaa']
# ...

# %% [markdown]
# # Classifying live tweets from trending topics

# %%
import pickle
with open('../Count vectorizer feature extraction/NBBoWTrained.sav', 'rb') as f:
    loaded_NB_classifier,loaded_func_countvectorizer = pickle.load(f)

# %%
count = 0
tweet_count = 0
bully_count = 0
bully_record = []

for value in trends: 
    for trend in value['trends']:
        if isEnglish(trend['name']): 
            print(trend['name'])
            tweets = tweepy.Cursor(api.search, q=trend['name'],lang="en", since=date_since,result_type='popular', timeout=999999).items(10)
            for tweet in tweets:
                print("Tweet:\n")
                cleaned_tweet = message_cleaning(tweet.text)
                print(cleaned_tweet)
                tweet_id = tweet.id
                print("Tweet ID: " + str(tweet_id))
                poster = tweet.user.screen_name
                print("\nPoster: " + poster + "\n")
                print("Replies to this tweet: \n")
                replies = tweepy.Cursor(api.search,q="@"+poster,lang="en" ,since_id=tweet_id).items(1000)
                #print(type(replies))
                count = 0
                for reply in replies:
                    if(reply.in_reply_to_status_id == tweet_id):
                        tweet_count += 1
                        input_text = []
                        input_text.append(reply.text)
                        print(input_text)
                        input_vector = loaded_func_countvectorizer.transform(input_text)
                        result = loaded_NB_classifier.predict(input_vector)
                        print("\nClassification:\n")
                        print(result)
                        if(result[0]):
                            bully_row = []
                            bully_count += 1
                            bully_row.append(reply.user.screen_name)
                            bully_row.append(poster)
                            bully_row.append(reply.text)
                            bully_record.append(bully_row)
                    if count==10:
                        break                
            count +=1
        if count==5:
            break
# Out:
# #WeDemandRRRMutualTeaser
# #MasterPromo4
# Tweet:
#
# ['lovely', 'ah', 'romantic', 'ah', 'oru', 'promo', 'way', 'wait', 'till', '6', 'pm', 'masterpromo4', 'master']
# Tweet ID: 1347513419113533440
#
# Poster: XBFilmCreators
#
# Replies to this tweet:
#
# ['@XBFilmCreators We want villan Promo also..!!!so plzzz ..who all Are need???']
#
# Classification:
#
# [0]
# ['@XBFilmCreators why you guys didnt release a trailer? these snippets are not good']
#
# Classification:
#
# [0]
# Tweet:
#
# ['sending', 'little', 'snippet', 'love', 'team', 'master', 'today', 'masterpromo4']
# Tweet ID: 1347524647219318787
#
# Poster: MalavikaM_
#
# Replies to this tweet:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-11eb9d8b4bd2> in <module>
#      21                 #print(type(replies))
#      22                 count = 0
# ---> 23                 for reply in replies:
# ...

# %% [markdown]
# # Classifying live tweets given a search keyword

# %%
print("\nEnter the search keyword: ")
query = input()
# Out:
# Enter the search keyword:
# messi

# %%
import time

tweet_count = 0
bully_count = 0
bully_record = []
date_since = '2021-01-11'
c=0

tweets = tweepy.Cursor(api.search, q=query,lang="en", since=date_since,result_type='popular', timeout=999999).items(10)
for tweet in tweets:
    print("Tweet:\n")
    cleaned_tweet = message_cleaning(tweet.text)
    print(cleaned_tweet)
    tweet_id = tweet.id
    print("Tweet ID: " + str(tweet_id))
    poster = tweet.user.screen_name
    print("\nPoster: " + poster + "\n")
    print("Replies to this tweet: \n")
    #replies = 
    #print(type(replies))

    count = 0
    for reply in tweepy.Cursor(api.search,q="@"+poster, since_id=tweet_id).items(1000):
        if(reply.in_reply_to_status_id == tweet_id):
            tweet_count += 1
            input_text = []
            input_text.append(reply.text)
            print(input_text)
            input_vector = loaded_func_countvectorizer.transform(input_text)
            result = loaded_NB_classifier.predict(input_vector)
            print("\nClassification:\n")
            print(result)
            if(result[0]):
                bully_row = []
                bully_count += 1
                bully_row.append(reply.user.screen_name)
                bully_row.append(poster)
                bully_row.append(reply.text)
                bully_record.append(bully_row)
        if count==10:
            break      
        c+=1
        if c % 700 == 0:  # first request completed, sleep 5 sec
            print("\nSleeping for 2 mins\n")
            time.sleep(150)
# Out:
# Tweet:
#
# ['five', 'year', 'ago', 'today', 'lionel', 'messi', 'became', 'first', 'player', 'history', 'win', 'ballon', 'five', 'time']
# Tweet ID: 1348688878417412096
#
# Poster: brfootball
#
# Replies to this tweet:
#
# ['@brfootball @mr_dzidzienyo They cheated for him']
#
# Classification:
#
# [1]
# ['@brfootball 😂 https://t.co/M8k8XYHRKg']
#
# Classification:
#
# [0]
#
# Sleeping for 2 mins
#
# ['@brfootball Elbarman 😹😹']
#
# Classification:
#
# [0]
# ['@brfootball https://t.co/KsMJ5tvTwN']
#
# Classification:
#
# [0]
# ["@brfootball Pendu formed his own Dubai'dor to satisfy his ego"]
#
# Classification:
#
# [0]
# ['@brfootball Ronaldo has more overall votes , cry.']
#
# Classification:
#
# [0]
# Tweet:
#
# ['5', 'year', 'ago', 'today', 'ballon', 'n', '5', 'n', 'messi', 'otd']
# Tweet ID: 1348594107023810565
#
# Poster: FCBarcelona
#
# Replies to this tweet:
#
# ['@FCBarcelona This man is the ONLY reason I still watch football. Simoly genius!']
#
# Classification:
#
# [1]
#
# ...

# %%
#TOO SLOW

tweet_count = 0
bully_count = 0
bully_record = []
date_since = '2021-01-08'

tweets = tweepy.Cursor(api.search, q=query,lang="en",since=date_since,result_type='popular', timeout=999999).items(10)
for tweet in tweets:
    print("Tweet:\n")
    cleaned_tweet = message_cleaning(tweet.text)
    print(cleaned_tweet)
    tweet_id = tweet.id
    print("Tweet ID: " + str(tweet_id))
    poster = tweet.user.screen_name
    print("\nPoster: " + poster + "\n")
    print("Replies to this tweet: \n")
    replies = tweepy.Cursor(api.search,q="@"+poster,since=date_since, since_id=tweet_id).items(1000)
    #print(type(replies))
    count = 0
    for reply in replies:
        if(reply.in_reply_to_status_id == tweet_id):
            tweet_count += 1
            input_text = []
            input_text.append(reply.text)
            print(input_text)
            input_vector = loaded_func_countvectorizer.transform(input_text)
            result = loaded_NB_classifier.predict(input_vector)
            print("\nClassification:\n")
            print(result)
            if(result[0]):
                bully_row = []
                bully_count += 1
                bully_row.append(reply.user.screen_name)
                bully_row.append(poster)
                bully_row.append(reply.text)
                bully_record.append(bully_row)
        if count==10:
            break
# Out:
# Tweet:
#
# ['2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '202']
# Tweet ID: 1347474404868022272
#
# Poster: goal
#
# Replies to this tweet:
#
# Tweet:
#
# ['laligasantander', 'free', 'kick', 'genius', 'messi', 'inspires', 'comeback', 'eventfu']
# Tweet ID: 1347407936184864768
#
# Poster: LaLigaEN
#
# Replies to this tweet:
#
# ['@LaLigaEN @Cristiano @juanmata8 Geniuses ❣️❣️❣️❣️']
#
# Classification:
#
# [0]
# ['@LaLigaEN @Cristiano @juanmata8 🔥']
#
# Classification:
#
# [0]
# Tweet:
#
# ['messi', 'washout', 'manchester', 'united', 'fan', 'want', 'see', 'lionel', 'messi', 'club']
# Tweet ID: 1347528481194860544
#
# Poster: sportbible
#
# Replies to this tweet:
#
# ['@sportbible Why tf would Messi wanna join United at the first place?😂😂']
#
# Classification:
#
# [1]
# Tweet:
#
# ['goal', 'every', '101', 'minute', 'lionel', 'messi', 'enjoy', 'facing', 'five', 'team', 'yet', 'score', 'ucl']
# ...

# %%
print("Total tweet:" + str(tweet_count))
print("Offensive tweets:" + str(bully_count))
#Offendor,victim and tweet in each record
print(bully_record)
# Out:
# Total tweet:22
# Offensive tweets:3
# [['NiiAmala', 'brfootball', '@brfootball @mr_dzidzienyo They cheated for him'], ['sunnydelight007', 'FCBarcelona', '@FCBarcelona This man is the ONLY reason I still watch football. Simoly genius!'], ['kruizmasterr', 'ESPNFC', '@ESPNFC Why is Ansu and Mason there tho?']]

# %%
print("Following tweets were detected as bullying")

i=0
for record in bully_record:
    i+=1
    print(str(i) + ") " + record[2])
    
print("Enter tweets confirmed as bullying")
x = input()
x = x.split()

print(x)

offenders = []
victims = []

for i in x:
    index = int(i)
    offenders.append(bully_record[index-1][0])
    victims.append(bully_record[index-1][1])
# Out:
# Following tweets were detected as bullying
# 1) @ESPNFC @SportsCenter I hate soccer but damn I gotta admit that’s crazy
# 2) @ESPNFC This man a legend. Still got all that testosterone running through his veins
# 3) @ESPNFC Damn 3 years my senior!  I pull a muscle just thinking of playing again!
# 4) @RoyNemer I’m not crying 😖
# 5) @RoyNemer Oh how i miss MSN !!!Good old days !!!
# 6) @RoyNemer I miss them 😭💙♥️... I miss this Barcelona
# 7) @RoyNemer I was at this game with my dad and I'll never forget it.
# 8) @RoyNemer @Messi_Meister 🥰💙❤️🥰 #MSN #Messi #Suárez #Neymar https://t.co/wdNm60voo9
# 9) @RoyNemer @Madikela06 It's not gonna happen this time around
# 10) @RoyNemer Neymar is so annoying. Looking at him in these pics drive me crazy. Messi and Suarez never bothered me.
# 11) @goal im a united fan but like cmon bro why tf is OGS even an option. he’s a fool compared to the other three.
# 12) @goal What the hell is Ole Gunnar's name doing in that list?
# ...

# %%
offenders = list(dict.fromkeys(offenders))
victims = list(dict.fromkeys(victims))

#for offender in offenders:
#    recipient_id = api.get_user(offender).id
#    try:
#        api.send_direct_message(recipient_id,"Please careful next time mate :)")
#        print("Message sent to offender")
#    except tweepy.TweepError as e:
#        print(e.reason)

#for victim in victims:
#    recipient_id = api.get_user(victim).id
#    try:
#        api.send_direct_message(recipient_id,"Hope you are OK. Have a good day")
#        print("Message sent to victim")
#    except tweepy.TweepError as e:
#        print(e.reason)
# Out:
# [{'code': 349, 'message': 'You cannot send messages to this user.'}]
# Message sent to victim

# %% [markdown]
# # Trying StreamListener

# %%
import tweepy
#override tweepy.StreamListener to add logic to on_status


class MyStreamListener(tweepy.StreamListener):

    def on_status(self, status):
        if 'RT @' in status.text:
            return
        print("\nTweet:")
        print(status.text)
        print("\nPosted by:")
        poster = status.user.screen_name
        print(poster)
        print("\nReplies to the tweet:")
        tweet_id = status.id
        replies = tweepy.Cursor(api.search,q="@"+poster, since_id=tweet_id).items(25)
        count = 0
        for reply in replies:
            if(reply.in_reply_to_status_id == tweet_id):
                print(reply.text)
                count +=1
            if count==50:
                break                        

myStreamListener = MyStreamListener()
myStream = tweepy.Stream(auth = api.auth, listener=myStreamListener)

for value in trends: 
    for trend in value['trends']:
        if isEnglish(trend['name']):
            myStream.filter(track=[trend['name']],languages=['en'])

# %%
import sys
import json
import time
import logging
import twitter
import urllib.parse

from os import environ as e

t = twitter.Api(
    consumer_key="ac8YRucGrIbNHUcD2IYqpfp4s",
    consumer_secret='ymifAZlIIJAVDqGfxcrVcmPCiEXYhxRUqyh43KVvyxmuuYG2s3',
    access_token_key='1033620667155984384-uKKn6iHzAan304XrH5nU8evIQJUwak',
    access_token_secret='6TcRuKZE4EGx5F2XTCavopZdttlw380Ms8MoyyMqZqiS2',
    sleep_on_rate_limit=True
)

def tweet_url(t):
    return "https://twitter.com/%s/status/%s" % (t.user.screen_name, t.id)

def get_replies():
    user = 'patrick_oshag'
    tweet_id = '1101551802930077696'
    max_id = None
    logging.info("looking for replies to: %s" % tweet_url(tweet))
    while True:
        q = urllib.parse.urlencode({"q": "to:%s" % user})
        try:
            replies = t.GetSearch(raw_query=q, since_id=tweet_id, max_id=max_id, count=20)
        except twitter.error.TwitterError as e:
            logging.error("caught twitter api error: %s", e)
            time.sleep(60)
            continue
        for reply in replies:
            logging.info("examining: %s" % tweet_url(reply))
            if reply.in_reply_to_status_id == tweet_id:
                logging.info("found reply: %s" % tweet_url(reply))
                yield reply
                # recursive magic to also get the replies to this reply
                for reply_to_reply in get_replies(reply):
                    yield reply_to_reply
            max_id = reply.id
        if len(replies) != 100:
            break
            
for reply in get_replies():
    print(reply.AsJsonString())

# %%
def get_twitter_url(user_name, status_id):
    return "https://twitter.com/" + str(user_name) + "/status/" + str(status_id)

url = get_twitter_url('afcjxmes', '1342501313771397121')
print(url)
